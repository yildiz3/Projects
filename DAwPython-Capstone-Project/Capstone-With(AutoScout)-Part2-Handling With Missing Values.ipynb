# %% [markdown]
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">The Capstone Project of Data Analytics Module</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:150%; text-align:center; border-radius:10px 10px;">Car Price Prediction EDA</p>

# %% [markdown]
# **``In this context, the project consists of 3 parts in general:``**
# * **The first part** is related to 'Data Cleaning'. It deals with Incorrect Headers, Incorrect Format, Anomalies, and Dropping useless columns.
# * **The second part** is related to 'Filling Data', in other words 'Imputation'. It deals with Missing Values. Categorical to numeric transformation is done as well.
# * **The third part** is related to 'Handling Outliers of Data' via Visualization libraries. So, some insights will be extracted.

# %% [markdown]
# # AutoScout - Part 2 - `( Handling With Missing Values )`

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt

import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

plt.rcParams["figure.figsize"] = (10,6)

sns.set_style("whitegrid")
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# Set it None to display all rows in the dataframe
# pd.set_option('display.max_rows', None)

# Set it to None to display all columns in the dataframe
pd.set_option('display.max_columns', None)

# %%
df0 = pd.read_csv("cleaned_AutoScout.csv")

# %%
df = df0.copy()

# %%
df.shape
# Out:
# (15919, 30)

# %%
df.duplicated().sum()
# Out:
# 1711

# %%
(df.isnull().sum() * 100 / df.shape[0]).sort_values(ascending=False)
# Out:
# Inspection_new        75.300
# Warranty              69.514
# Weight_kg             43.809
# Drive chain           43.081
# Previous Owners       41.711
# Cylinders             35.681
# Upholstery_type       30.599
# Gears                 29.600
# vat                   28.350
# Emission Class        22.790
# Extras                18.607
# CO2 Emission          15.302
# cons_city             15.302
# cons_country          14.926
# cons_comb             12.771
# age                   10.032
# entertainment_media    8.631
# km                     6.433
# safety_security        6.169
# Nr. of Seats           6.137
# comfort_convenience    5.779
# Displacement_cc        3.116
# Nr. of Doors           1.332
# body_type              0.377
# Type                   0.013
# Fuel                   0.000
# Gearing Type           0.000
# kW                     0.000
# price                  0.000
# make_model             0.000
# dtype: float64

# %%
# % of missing.
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# make_model - 0%
# body_type - 0%
# price - 0%
# vat - 28%
# km - 6%
# kW - 0%
# Type - 0%
# Previous Owners - 42%
# Warranty - 70%
# Nr. of Doors - 1%
# Nr. of Seats - 6%
# Gearing Type - 0%
# Cylinders - 36%
# Drive chain - 43%
# Fuel - 0%
# CO2 Emission - 15%
# Emission Class - 23%
# comfort_convenience - 6%
# entertainment_media - 9%
# Extras - 19%
# safety_security - 6%
# Gears - 30%
# Inspection_new - 75%
# age - 10%
# Upholstery_type - 31%
# Displacement_cc - 3%
# Weight_kg - 44%
# cons_comb - 13%
# cons_city - 15%
# cons_country - 15%

# %%
df.head(3).T
# Out:
#                                                                      0  \
# make_model                                                     Audi A1
# body_type                                                       Sedans
# price                                                            15770
# vat                                                     VAT deductible
# km                                                           56013.000
# kW                                                              66.000
# Type                                                              Used
# Previous Owners                                                  2.000
# Warranty                                                           NaN
# Nr. of Doors                                                     5.000
# Nr. of Seats                                                     5.000
# Gearing Type                                                 Automatic
# Cylinders                                                        3.000
# Drive chain                                                      front
# Fuel                                                            Diesel
# CO2 Emission                                                    99.000
# Emission Class                                                   Euro6
# comfort_convenience  Air conditioning,Armrest,Automatic climate con...
# entertainment_media  Bluetooth,Hands-free equipment,On-board comput...
# Extras                  Alloy wheels,Catalytic Converter,Voice Control
# safety_security      ABS,Central door lock,Daytime running lights,D...
# Gears                                                              NaN
# Inspection_new                                                     Yes
# age                                                              3.000
# Upholstery_type                                                  Cloth
# Displacement_cc                                               1422.000
# Weight_kg                                                     1220.000
# cons_comb                                                        3.800
# cons_city                                                        4.300
# cons_country                                                     3.500
#
#                                                                      1  \
# make_model                                                     Audi A1
# body_type                                                       Sedans
# price                                                            14500
# vat                                                   Price negotiable
# km                                                           80000.000
# kW                                                             141.000
# Type                                                              Used
# Previous Owners                                                    NaN
# Warranty                                                           NaN
# Nr. of Doors                                                     3.000
# Nr. of Seats                                                     4.000
# Gearing Type                                                 Automatic
# Cylinders                                                        4.000
# Drive chain                                                      front
# Fuel                                                           Benzine
# CO2 Emission                                                   129.000
# Emission Class                                                   Euro6
# comfort_convenience  Air conditioning,Automatic climate control,Hil...
# entertainment_media  Bluetooth,Hands-free equipment,On-board comput...
# Extras               Alloy wheels,Sport seats,Sport suspension,Voic...
# safety_security      ABS,Central door lock,Central door lock with r...
# Gears                                                            7.000
# Inspection_new                                                     NaN
# age                                                              2.000
# Upholstery_type                                                  Cloth
# Displacement_cc                                               1798.000
# Weight_kg                                                     1255.000
# cons_comb                                                        5.600
# cons_city                                                        7.100
# cons_country                                                     4.700
#
#                                                                      2
# make_model                                                     Audi A1
# body_type                                                       Sedans
# price                                                            14640
# vat                                                     VAT deductible
# km                                                           83450.000
# kW                                                              85.000
# Type                                                              Used
# Previous Owners                                                  1.000
# Warranty                                                           NaN
# Nr. of Doors                                                     4.000
# Nr. of Seats                                                     4.000
# Gearing Type                                                 Automatic
# Cylinders                                                          NaN
# Drive chain                                                      front
# Fuel                                                            Diesel
# CO2 Emission                                                    99.000
# Emission Class                                                   Euro6
# comfort_convenience  Air conditioning,Cruise control,Electrical sid...
# entertainment_media                              MP3,On-board computer
# Extras                                      Alloy wheels,Voice Control
# safety_security      ABS,Central door lock,Daytime running lights,D...
# Gears                                                              NaN
# Inspection_new                                                     NaN
# age                                                              3.000
# Upholstery_type                                                  Cloth
# Displacement_cc                                               1598.000
# Weight_kg                                                          NaN
# cons_comb                                                        3.800
# cons_city                                                        4.400
# cons_country                                                     3.400

# %%
df.sample(3).T
# Out:
#                              11689  \
# make_model           Opel Insignia
# body_type                    Other
# price                        17690
# vat                            NaN
# km                       21517.000
# kW                         100.000
# Type                          Used
# Previous Owners              1.000
# Warranty                       NaN
# Nr. of Doors                 5.000
# Nr. of Seats                 5.000
# Gearing Type                Manual
# Cylinders                    4.000
# Drive chain                    NaN
# Fuel                        Diesel
# CO2 Emission               114.000
# Emission Class               Euro6
# comfort_convenience            NaN
# entertainment_media            NaN
# Extras                         NaN
# safety_security                NaN
# Gears                        6.000
# Inspection_new                 NaN
# age                          2.000
# Upholstery_type                NaN
# Displacement_cc           1598.000
# Weight_kg                 1503.000
# cons_comb                    4.300
# cons_city                    5.100
# cons_country                 3.900
#
#                                                                  3757   \
# make_model                                                     Audi A3
# body_type                                                       Sedans
# price                                                            21990
# vat                                                     VAT deductible
# km                                                           36306.000
# kW                                                             137.000
# Type                                                              Used
# Previous Owners                                                  1.000
# Warranty                                                           NaN
# Nr. of Doors                                                     4.000
# Nr. of Seats                                                     5.000
# Gearing Type                                                 Automatic
# Cylinders                                                          NaN
# Drive chain                                                        NaN
# Fuel                                                           Benzine
# CO2 Emission                                                       NaN
# Emission Class                                                     NaN
# comfort_convenience  Air conditioning,Armrest,Automatic climate con...
# entertainment_media  Bluetooth,Hands-free equipment,On-board comput...
# Extras                                                    Alloy wheels
# safety_security      ABS,Alarm system,Central door lock,Daytime run...
# Gears                                                              NaN
# Inspection_new                                                     Yes
# age                                                              2.000
# Upholstery_type                                           Full leather
# Displacement_cc                                               1984.000
# Weight_kg                                                          NaN
# cons_comb                                                          NaN
# cons_city                                                          NaN
# cons_country                                                       NaN
#
#                                                                  13106
# make_model                                                Renault Clio
# body_type                                                       Sedans
# price                                                            15900
# vat                                                     VAT deductible
# km                                                           14280.000
# kW                                                              87.000
# Type                                                              Used
# Previous Owners                                                  1.000
# Warranty                                                           NaN
# Nr. of Doors                                                     5.000
# Nr. of Seats                                                     5.000
# Gearing Type                                                 Automatic
# Cylinders                                                        4.000
# Drive chain                                                        NaN
# Fuel                                                           Benzine
# CO2 Emission                                                   120.000
# Emission Class                                                   Euro6
# comfort_convenience  Air conditioning,Cruise control,Electrical sid...
# entertainment_media  Bluetooth,Digital radio,Hands-free equipment,M...
# Extras                                       Alloy wheels,Touch screen
# safety_security      ABS,Daytime running lights,Driver-side airbag,...
# Gears                                                            6.000
# Inspection_new                                                     NaN
# age                                                              1.000
# Upholstery_type                                           Part leather
# Displacement_cc                                               1197.000
# Weight_kg                                                          NaN
# cons_comb                                                        5.400
# cons_city                                                        6.800
# cons_country                                                     4.500

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Data columns (total 30 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   make_model           15919 non-null  object
#  1   body_type            15859 non-null  object
#  2   price                15919 non-null  int64
#  3   vat                  11406 non-null  object
#  4   km                   14895 non-null  float64
#  5   kW                   15919 non-null  float64
#  6   Type                 15917 non-null  object
#  7   Previous Owners      9279 non-null   float64
#  8   Warranty             4853 non-null   float64
#  9   Nr. of Doors         15707 non-null  float64
#  10  Nr. of Seats         14942 non-null  float64
#  11  Gearing Type         15919 non-null  object
#  12  Cylinders            10239 non-null  float64
#  13  Drive chain          9061 non-null   object
#  14  Fuel                 15919 non-null  object
#  15  CO2 Emission         13483 non-null  float64
#  16  Emission Class       12291 non-null  object
#  17  comfort_convenience  14999 non-null  object
#  18  entertainment_media  14545 non-null  object
#  19  Extras               12957 non-null  object
#  20  safety_security      14937 non-null  object
#  21  Gears                11207 non-null  float64
#  22  Inspection_new       3932 non-null   object
#  23  age                  14322 non-null  float64
#  24  Upholstery_type      11048 non-null  object
#  25  Displacement_cc      15423 non-null  float64
#  26  Weight_kg            8945 non-null   float64
#  27  cons_comb            13886 non-null  float64
#  28  cons_city            13483 non-null  float64
#  29  cons_country         13543 non-null  float64
# dtypes: float64(15), int64(1), object(14)
# memory usage: 3.6+ MB

# %%
sns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap='viridis');

# %%
df.columns
# Out:
# Index(['make_model', 'body_type', 'price', 'vat', 'km', 'kW', 'Type',
#        'Previous Owners', 'Warranty', 'Nr. of Doors', 'Nr. of Seats',
#        'Gearing Type', 'Cylinders', 'Drive chain', 'Fuel', 'CO2 Emission',
#        'Emission Class', 'comfort_convenience', 'entertainment_media',
#        'Extras', 'safety_security', 'Gears', 'Inspection_new', 'age',
#        'Upholstery_type', 'Displacement_cc', 'Weight_kg', 'cons_comb',
#        'cons_city', 'cons_country'],
#       dtype='object')

# %%
# We defined a function that shows the first info of the column

def info(col):
    print("Column Name    : ", col)
    print("--------------------------------")
    print("Number of Nulls       : ", df[col].isnull().sum())
    print("Percentage of Nulls   : ", "%", round(df[col].isnull().sum()/df.shape[0]*100, 2))
    print("Number of Uniques     : ", df[col].nunique())
    print("--------------------------------\n")
    print(df[col].value_counts(dropna = False))

# %%
def fill_with(df, group_col1, group_col2, col_name, method):
    
    if method == "mode":
        for group1 in list(df[group_col1].unique()):
            for group2 in list(df[group_col2].unique()):
                cond1 = df[group_col1]==group1
                cond2 = (df[group_col1]==group1) & (df[group_col2]==group2)
                mode1 = list(df[cond1][col_name].mode())
                mode2 = list(df[cond2][col_name].mode())
                if mode2 != []:
                    df.loc[cond2, col_name] = df.loc[cond2, col_name].fillna(df[cond2][col_name].mode()[0])
                elif mode1 != []:
                    df.loc[cond2, col_name] = df.loc[cond2, col_name].fillna(df[cond1][col_name].mode()[0])
                else:
                    df.loc[cond2, col_name] = df.loc[cond2, col_name].fillna(df[col_name].mode()[0])
                
    elif method == "mean":
        for group1 in list(df[group_col1].unique()):
            for group2 in list(df[group_col2].unique()):
                cond1 = df[group_col1]==group1
                cond2 = (df[group_col1]==group1) & (df[group_col2]==group2)
                df.loc[cond2, col_name] = df.loc[cond2, col_name].fillna(df[cond2][col_name].mean()).fillna(df[cond1][col_name].mean()).fillna(df[col_name].mean())


    elif method == "median":
        for group1 in list(df[group_col1].unique()):
            for group2 in list(df[group_col2].unique()):
                cond1 = df[group_col1]==group1
                cond2 = (df[group_col1]==group1) & (df[group_col2]==group2)
                df.loc[cond2, col_name] = df.loc[cond2, col_name].fillna(df[cond2][col_name].median()).fillna(df[cond1][col_name].median()).fillna(df[col_name].mean())

    elif method == "ffill":           
        for group1 in list(df[group_col1].unique()):
            for group2 in list(df[group_col2].unique()):
                cond2 = (df[group_col1]==group1) & (df[group_col2]==group2)
                df.loc[cond2, col_name] = df.loc[cond2, col_name].fillna(method="ffill").fillna(method="bfill")
                
        for group1 in list(df[group_col1].unique()):
            cond1 = df[group_col1]==group1
            df.loc[cond1, col_name] = df.loc[cond1, col_name].fillna(method="ffill").fillna(method="bfill")            
           
        df[col_name] = df[col_name].fillna(method="ffill").fillna(method="bfill")
    
    print("Number of NaN : ",df[col_name].isnull().sum())
    print("------------------")
    print(df[col_name].value_counts(dropna=False))

# %% [markdown]
# How to use ***fill_with(df, group_col1, group_col2, col_name, method)***
#
# ***df :***            Data Frame
#
# :***group_col1 :***   col_name values will be grouped according to this column. The values of this column  will be taken for the next phase
#
# :***group_col2 :***  col_name values will be grouped according to this column too. The values of this column  will be taken for the next phase
#
# :***col_name :***    We will fill the rows with 'null' values in this column
#
# :***method :***      Choose a method to fill Null values with "mode", "mean", "median", "ffill"

# %% [markdown]
# ## - make_model

# %%
info("make_model")
# Out:
# Column Name    :  make_model
# --------------------------------
# Number of Nulls       :  0
# Percentage of Nulls   :  % 0.0
# Number of Uniques     :  9
# --------------------------------
#
# Audi A3           3097
# Audi A1           2614
# Opel Insignia     2598
# Opel Astra        2526
# Opel Corsa        2219
# Renault Clio      1839
# Renault Espace     991
# Renault Duster      34
# Audi A2              1
# Name: make_model, dtype: int64

# %% [markdown]
# ## - age

# %%
info('age')
# Out:
# Column Name    :  age
# --------------------------------
# Number of Nulls       :  1597
# Percentage of Nulls   :  % 10.03
# Number of Uniques     :  4
# --------------------------------
#
# 1.000    4522
# 3.000    3674
# 2.000    3273
# 0.000    2853
# NaN      1597
# Name: age, dtype: int64

# %%
df['age'].fillna('-', inplace=True)

# %%
df[df["age"] == "-"]["km"].value_counts(dropna=False)
# Out:
# NaN          838
# 10.000       369
# 1.000        146
# 5.000         58
# 20.000        32
# 15.000        21
# 0.000         19
# 11.000        12
# 8.000         11
# 50.000        10
# 12.000         8
# 100.000        8
# 7.000          7
# 3.000          4
# 9.000          4
# 4.000          3
# 250.000        3
# 25.000         3
# 30.000         3
# 3000.000       2
# 39962.000      2
# 2.000          2
# 22627.000      2
# 784.000        1
# 89692.000      1
# 3500.000       1
# 325.000        1
# 497.000        1
# 99.000         1
# 77.000         1
# 40.000         1
# 19500.000      1
# 6100.000       1
# 11000.000      1
# 89982.000      1
# 4307.000       1
# 141.000        1
# 34164.000      1
# 500.000        1
# 150.000        1
# 11200.000      1
# 20768.000      1
# 32084.000      1
# 142.000        1
# 81800.000      1
# 281.000        1
# 6.000          1
# 68485.000      1
# 85000.000      1
# 196.000        1
# 4500.000       1
# 60.000         1
# 5000.000       1
# Name: km, dtype: int64

# %%
cond1 = (df['km'] < 10000)
cond2 = ((df['km'] >= 10000) & (df['km'] < 28000))
cond3 = ((df['km'] >= 28000) & (df['km'] < 50000))
cond4 = (df['km'] >= 50000)

# %%
df.loc[cond1,'age'] = df.loc[cond1,'age'].replace('-', 0)
df.loc[cond2,'age'] = df.loc[cond2,'age'].replace('-', 1)
df.loc[cond3,'age'] = df.loc[cond3,'age'].replace('-', 2)
df.loc[cond4,'age'] = df.loc[cond4,'age'].replace('-', 3)

# %%
df.groupby('age').km.mean()
# Out:
# age
# 0.0    1647.363
# 1.0   18035.130
# 2.0   41748.577
# 3.0   77450.063
# -           NaN
# Name: km, dtype: float64

# %%
df["age"].value_counts(dropna=False)
# Out:
# 1.0    4528
# 3.0    3679
# 0.0    3597
# 2.0    3277
# -       838
# Name: age, dtype: int64

# %%
df.groupby(['make_model',"body_type", 'age']).price.describe()
# Out:
#                                count      mean      std       min       25%  \
# make_model     body_type age
# Audi A1        Compact   0.0 198.000 23277.434 3510.406 14900.000 20503.500
#                          1.0 268.000 18596.041 2659.910 13980.000 16445.000
#                          2.0 161.000 16602.807 2085.384 10999.000 15450.000
#                          3.0 234.000 14532.910 1908.909  9950.000 13407.500
#                          -   178.000 23996.264 3383.852 16220.000 21515.000
# ...                              ...       ...      ...       ...       ...
# Renault Espace Van       0.0 218.000 40074.514 8154.729 24200.000 32975.000
#                          1.0 207.000 31947.841 4072.970 23099.000 29385.000
#                          2.0 134.000 26574.478 3427.863 14600.000 24982.500
#                          3.0 199.000 22132.623 3216.032 12614.000 19900.000
#                          -    19.000 39632.316 6866.139 28650.000 33848.000
#
#                                    50%       75%       max
# make_model     body_type age
# Audi A1        Compact   0.0 22492.000 26798.500 31990.000
#                          1.0 16980.000 20950.000 23829.000
#                          2.0 15850.000 17700.000 22150.000
#                          3.0 13994.500 15480.000 18900.000
#                          -   22875.000 27380.000 29181.000
# ...                                ...       ...       ...
# Renault Espace Van       0.0 38925.000 45667.250 68320.000
#                          1.0 31900.000 34990.000 38990.000
#                          2.0 25490.000 28500.000 33800.000
#                          3.0 22222.000 24650.000 27900.000
#                          -   39550.000 45950.500 50170.000
#
# [176 rows x 8 columns]

# %%
df['age'].replace('-', 0, inplace=True)

# %%
df.groupby('age').km.mean()
# Out:
# age
# 0.000    1647.363
# 1.000   18035.130
# 2.000   41748.577
# 3.000   77450.063
# Name: km, dtype: float64

# %%
df["age"].value_counts(dropna=False)
# Out:
# 1.000    4528
# 0.000    4435
# 3.000    3679
# 2.000    3277
# Name: age, dtype: int64

# %% [markdown]
# ## - km

# %%
info('km')
# Out:
# Column Name    :  km
# --------------------------------
# Number of Nulls       :  1024
# Percentage of Nulls   :  % 6.43
# Number of Uniques     :  6689
# --------------------------------
#
# 10.000       1045
# NaN          1024
# 1.000         367
# 5.000         170
# 50.000        148
#              ...
# 67469.000       1
# 43197.000       1
# 10027.000       1
# 35882.000       1
# 57.000          1
# Name: km, Length: 6690, dtype: int64

# %%
df.groupby(["age", "Fuel"])["km"].describe()
# Out:
#                   count       mean       std       min       25%       50%  \
# age   Fuel
# 0.000 Benzine  2769.000   1519.261  3897.309     0.000    10.000    12.000
#       Diesel    674.000   2190.536  7525.704     0.000    10.000    29.000
#       LPG/CNG     7.000     20.714    27.004     1.000     4.000     8.000
# 1.000 Benzine  2618.000  16507.555 10618.632     1.000  8307.250 15753.000
#       Diesel   1865.000  20178.379 11293.286     1.000 13250.000 20490.000
#       Electric    3.000  15560.000  4694.337 12000.000 12900.000 13800.000
#       LPG/CNG     4.000  20400.000  8380.931 11000.000 15500.000 20000.000
# 2.000 Benzine  1312.000  31241.345 20701.351     1.000 16940.500 26696.000
#       Diesel   1947.000  48698.427 30383.195     1.000 25753.000 40306.000
#       LPG/CNG    17.000  56697.353 33673.949  2880.000 40000.000 56000.000
# 3.000 Benzine  1126.000  50829.898 26256.291  1800.000 32000.000 46022.500
#       Diesel   2527.000  89077.307 38148.199    10.000 61757.000 86071.000
#       Electric    2.000  40431.500 23431.397 23863.000 32147.250 40431.500
#       LPG/CNG    24.000 105212.375 31615.712 51500.000 90131.750 95117.000
#
#                       75%        max
# age   Fuel
# 0.000 Benzine    1150.000 105000.000
#       Diesel     2000.000 127022.000
#       LPG/CNG      34.000     60.000
# 1.000 Benzine   24352.250  80009.000
#       Diesel    26300.000 136000.000
#       Electric  17340.000  20880.000
#       LPG/CNG   24900.000  30600.000
# 2.000 Benzine   44000.000 317000.000
#       Diesel    67000.000 240000.000
#       LPG/CNG   77000.000 120000.000
# 3.000 Benzine   65537.500 146210.000
#       Diesel   112000.000 291800.000
#       Electric  48715.750  57000.000
#       LPG/CNG  120425.000 175000.000

# %%
fill_with(df, "age", "Fuel", "km", "mean")
# Out:
# Number of NaN :  0
# ------------------
# 10.000       1045
# 1519.261      717
# 1.000         367
# 2190.536      256
# 5.000         170
#              ...
# 67469.000       1
# 43197.000       1
# 10027.000       1
# 35882.000       1
# 57.000          1
# Name: km, Length: 6695, dtype: int64

# %% [markdown]
# ## - body_type

# %%
info("body_type")
# Out:
# Column Name    :  body_type
# --------------------------------
# Number of Nulls       :  60
# Percentage of Nulls   :  % 0.38
# Number of Uniques     :  9
# --------------------------------
#
# Sedans           7903
# Station wagon    3553
# Compact          3153
# Van               783
# Other             290
# Transporter        88
# NaN                60
# Off-Road           56
# Coupe              25
# Convertible         8
# Name: body_type, dtype: int64

# %%
df["body_type"].replace("Other", np.nan, inplace=True)

# %%
df.groupby(["make_model", "age", "body_type"]).price.describe().T
# Out:
# make_model   Audi A1                                                        \
# age            0.000                                       1.000
# body_type    Compact    Sedans Station wagon       Van   Compact    Sedans
# count        376.000   418.000         2.000     1.000   268.000   465.000
# mean       23617.731 24059.818     28944.500 29000.000 18596.041 18394.938
# std         3465.174  3282.827        77.075       NaN  2659.910  2588.159
# min        14900.000 15980.000     28890.000 29000.000 13980.000 13450.000
# 25%        20990.000 21700.000     28917.250 29000.000 16445.000 16321.000
# 50%        22720.000 23660.000     28944.500 29000.000 16980.000 16950.000
# 75%        26990.000 26890.000     28971.750 29000.000 20950.000 20350.000
# max        31990.000 37900.000     28999.000 29000.000 23829.000 33900.000
#
# make_model                                                            \
# age                          2.000
# body_type  Station wagon   Compact     Coupe    Sedans Station wagon
# count             11.000   161.000     1.000   266.000         3.000
# mean           17410.909 16602.807 15900.000 16605.395     17613.333
# std             2166.031  2085.384       NaN  2223.979      2953.817
# min            15750.000 10999.000 15900.000 11600.000     14750.000
# 25%            15870.000 15450.000 15900.000 14955.000     16095.000
# 50%            16480.000 15850.000 15900.000 15900.000     17440.000
# 75%            18260.000 17700.000 15900.000 18000.000     19045.000
# max            21450.000 22150.000 15900.000 22500.000     20650.000
#
# make_model                                               Audi A2   Audi A3  \
# age            3.000                                       1.000     0.000
# body_type    Compact     Coupe    Sedans Station wagon  Off-Road   Compact
# count        234.000     1.000   389.000         5.000     1.000    21.000
# mean       14532.910 13950.000 14466.900     14358.000 28200.000 28628.714
# std         1908.909       NaN  1890.278      1276.891       NaN  7999.524
# min         9950.000 13950.000  8999.000     12950.000 28200.000 15500.000
# 25%        13407.500 13950.000 13000.000     13979.000 28200.000 22675.000
# 50%        13994.500 13950.000 13950.000     13999.000 28200.000 25228.000
# 75%        15480.000 13950.000 15784.000     14440.000 28200.000 36840.000
# max        18900.000 13950.000 19900.000     16422.000 28200.000 41495.000
#
# make_model                                                          \
# age                                    1.000
# body_type     Sedans Station wagon   Compact Convertible    Sedans
# count        692.000       111.000    29.000       3.000   709.000
# mean       24860.812     24590.766 22030.931   29664.333 22544.715
# std         2359.800      4152.131  4270.469   23557.901  5224.410
# min        18820.000     17990.000 14500.000   10893.000 14250.000
# 25%        23687.500     23072.000 19999.000   16446.500 20800.000
# 50%        24890.000     24420.000 21900.000   22000.000 21500.000
# 75%        26200.000     25420.000 22599.000   39050.000 22900.000
# max        62900.000     63900.000 39959.000   56100.000 74600.000
#
# make_model                                                          \
# age                          2.000
# body_type  Station wagon   Compact Convertible     Coupe    Sedans
# count             32.000    39.000       4.000     1.000   550.000
# mean           21252.594 20489.769   28562.500 19000.000 19980.358
# std             3201.415  8208.445    5301.159       NaN  3721.376
# min             5555.000 13790.000   20900.000 19000.000 10550.000
# 25%            20650.000 17525.000   27350.000 19000.000 18000.000
# 50%            21480.000 18945.000   30200.000 19000.000 19400.000
# 75%            22900.000 20780.000   31412.500 19000.000 20990.000
# max            23800.000 67600.000   32950.000 19000.000 55000.000
#
# make_model                                                          \
# age                          3.000
# body_type  Station wagon   Compact Convertible     Coupe    Sedans
# count             72.000    93.000       1.000     3.000   647.000
# mean           19010.875 15303.796   20000.000 17326.667 16702.832
# std             1522.622  2256.723         NaN   583.124  2900.228
# min            14590.000 12900.000   20000.000 16990.000 10950.000
# 25%            18374.500 13500.000   20000.000 16990.000 15110.000
# 50%            18990.000 14900.000   20000.000 16990.000 15980.000
# 75%            19621.250 16895.000   20000.000 17495.000 17890.000
# max            21990.000 24950.000   20000.000 18000.000 42500.000
#
# make_model               Opel Astra                                    \
# age                           0.000
# body_type  Station wagon    Compact     Coupe    Sedans Station wagon
# count             67.000     61.000     1.000   334.000       285.000
# mean           15739.507  22003.738 29990.000 20300.404     22390.312
# std             1883.567   7172.985       NaN  4391.644      5047.741
# min            11790.000  15816.000 29990.000  6950.000     15285.000
# 25%            14195.000  16990.000 29990.000 17211.250     18070.000
# 50%            15900.000  17800.000 29990.000 18512.500     20185.000
# 75%            17250.000  26899.000 29990.000 23613.750     26441.000
# max            18780.000  39433.000 29990.000 32950.000     34900.000
#
# make_model                                                                  \
# age            1.000                                       2.000
# body_type    Compact  Off-Road    Sedans Station wagon   Compact    Sedans
# count         39.000     1.000   320.000       332.000    55.000   249.000
# mean       14717.538 18590.000 15682.544     16882.630 13091.491 12954.040
# std         1266.385       NaN  1794.249      1943.277  1884.243  2080.899
# min        11999.000 18590.000  8860.000       255.000  9999.000  7800.000
# 25%        13990.000 18590.000 14537.250     15200.000 11955.000 11320.000
# 50%        14900.000 18590.000 15275.000     17355.000 12636.000 12500.000
# 75%        14990.000 18590.000 17205.000     18465.750 12955.000 14900.000
# max        18900.000 18590.000 18990.000     18990.000 19950.000 17890.000
#
# make_model                                                            \
# age                          3.000
# body_type  Station wagon   Compact     Coupe    Sedans Station wagon
# count            269.000    30.000     1.000   150.000       325.000
# mean           13093.089 12023.733 14490.000 11899.480     11047.557
# std             2017.233  2767.419       NaN  2304.464      2526.506
# min             8480.000  8450.000 14490.000  6500.000      6000.000
# 25%            11850.000 10111.250 14490.000 10400.000      9479.000
# 50%            12660.000 10947.500 14490.000 10950.000     10500.000
# 75%            14650.000 14854.250 14490.000 13967.500     12000.000
# max            17890.000 17750.000 14490.000 15999.000     15999.000
#
# make_model Opel Corsa                                                      \
# age             0.000                                     1.000
# body_type     Compact     Coupe    Sedans Transporter   Compact    Sedans
# count         506.000     3.000   192.000       3.000   353.000   281.000
# mean        13783.897 10283.333 12910.297    9933.333 11913.510 10814.836
# std          2666.969  1286.792  2593.260     493.288  2098.742  1985.520
# min           120.000  8800.000  8200.000    9600.000  7499.000    13.000
# 25%         10979.000  9875.000 10990.000    9650.000  9800.000  9499.000
# 50%         14750.000 10950.000 11300.000    9700.000 12750.000  9900.000
# 75%         15979.750 11025.000 15390.000   10100.000 13890.000 12500.000
# max         18622.000 11100.000 18490.000   10500.000 15790.000 15690.000
#
# make_model                                                               \
# age            2.000                                              3.000
# body_type    Compact     Coupe Off-Road    Sedans Transporter   Compact
# count        158.000     5.000    3.000   199.000       1.000   213.000
# mean        9683.411  8718.000 8166.667  9000.975    7450.000  8426.765
# std         1782.282  1356.695  461.880  1513.124         NaN  2065.760
# min         6250.000  7500.000 7900.000  6200.000    7450.000  4990.000
# 25%         8500.000  7900.000 7900.000  8299.000    7450.000  7290.000
# 50%         8950.000  8500.000 7900.000  8600.000    7450.000  7750.000
# 75%        11261.250  8700.000 8300.000  8950.000    7450.000  7950.000
# max        13990.000 10990.000 8700.000 13900.000    7450.000 16950.000
#
# make_model                                          Opel Insignia            \
# age                                                         0.000
# body_type      Coupe    Sedans Transporter      Van       Compact  Off-Road
# count          5.000   203.000       3.000    2.000        17.000     6.000
# mean        7920.000  7985.808    5433.333 7900.000     35967.765 32234.833
# std         1478.851  1449.380     175.594    0.000      6435.598  2137.208
# min         6900.000  4950.000    5250.000 7900.000     21900.000 28500.000
# 25%         7200.000  7400.000    5350.000 7900.000     34995.000 31715.000
# 50%         7200.000  7650.000    5450.000 7900.000     36490.000 32569.000
# 75%         7800.000  7900.000    5525.000 7900.000     38995.000 33315.750
# max        10500.000 13500.000    5600.000 7900.000     49884.000 34776.000
#
# make_model                                                            \
# age                                    1.000
# body_type     Sedans Station wagon   Compact    Sedans Station wagon
# count        251.000       392.000     2.000   278.000       480.000
# mean       30772.112     32859.796 20400.000 20368.583     21973.621
# std         5798.167      5013.867   707.107  2439.116      1654.916
# min        19902.000     19900.000 19900.000 15990.000     17500.000
# 25%        25670.000     29248.750 20150.000 18990.000     20850.000
# 50%        30790.000     33450.000 20400.000 19995.000     21900.000
# 75%        34958.000     36590.250 20650.000 21490.000     23480.000
# max        49350.000     52120.000 20900.000 38900.000     24700.000
#
# make_model                                                                  \
# age                      2.000                                       3.000
# body_type        Van   Compact     Coupe    Sedans Station wagon   Compact
# count          1.000     4.000     1.000   245.000       305.000     4.000
# mean       20980.000 17545.000 17094.000 16575.776     17493.898 12375.000
# std              NaN  3341.262       NaN  3254.280      2614.542  2373.640
# min        20980.000 13490.000 17094.000  9900.000      8990.000 10350.000
# 25%        20980.000 15740.000 17094.000 13540.000     15900.000 10350.000
# 50%        20980.000 17695.000 17094.000 17750.000     17960.000 12125.000
# 75%        20980.000 19500.000 17094.000 18890.000     18990.000 14150.000
# max        20980.000 21300.000 17094.000 21990.000     21990.000 14900.000
#
# make_model                                   Renault Clio                      \
# age                                                 0.000
# body_type   Off-Road    Sedans Station wagon      Compact  Off-Road    Sedans
# count          1.000   126.000       434.000      177.000     1.000   171.000
# mean       12750.000 13411.048     13673.684    11841.876 17990.000 11900.994
# std              NaN  2251.593      2165.299     2748.388       NaN  3304.796
# min        12750.000  8600.000      8290.000     9545.000 17990.000  6950.000
# 25%        12750.000 11950.000     12400.000    10790.000 17990.000 10250.000
# 50%        12750.000 13445.000     13900.000    11190.000 17990.000 10990.000
# 75%        12750.000 14980.000     14993.750    11400.000 17990.000 11400.000
# max        12750.000 17999.000     18400.000    26770.000 17990.000 26970.000
#
# make_model                                                              \
# age                                      1.000
# body_type  Station wagon Transporter   Compact    Sedans Station wagon
# count             43.000       3.000   134.000   308.000        98.000
# mean           12745.860    9661.333 15835.754 15270.649     11924.622
# std             3322.208     691.666  4597.178  5487.220      2977.329
# min             6900.000    9262.000  8990.000  8480.000      7950.000
# 25%            10977.000    9262.000 13387.500 10200.000     10000.000
# 50%            11450.000    9262.000 15500.000 14920.000     10450.000
# 75%            14987.000    9861.000 16573.250 18490.000     14775.000
# max            20680.000   10460.000 29740.000 31500.000     20800.000
#
# make_model                                                                   \
# age                                 2.000
# body_type  Transporter      Van   Compact     Coupe    Sedans Station wagon
# count            6.000    1.000    86.000     1.000   230.000        99.000
# mean         10058.500 9900.000 12484.372 17990.000 10121.900     11288.848
# std            761.313      NaN  3428.348       NaN  2536.429      2708.793
# min           8990.000 9900.000  6950.000 17990.000  6990.000      6000.000
# 25%           9513.750 9900.000  8990.000 17990.000  8500.000      9394.500
# 50%          10188.000 9900.000 13390.000 17990.000  9500.000      9980.000
# 75%          10720.500 9900.000 13925.000 17990.000  9900.000     12000.000
# max          10798.000 9900.000 27900.000 17990.000 22000.000     17750.000
#
# make_model                                                                  \
# age                                 3.000
# body_type  Transporter      Van   Compact Off-Road    Sedans Station wagon
# count            9.000    1.000    87.000    1.000   209.000        97.000
# mean          8415.556 9400.000  9549.011 7700.000  9348.115      9437.845
# std            839.674      NaN  2732.518      NaN  2769.832      2481.119
# min           6900.000 9400.000  5800.000 7700.000  5445.000      5900.000
# 25%           7800.000 9400.000  7875.000 7700.000  7699.000      7999.000
# 50%           8590.000 9400.000  8400.000 7700.000  8400.000      8490.000
# 75%           8990.000 9400.000 12545.000 7700.000 10490.000     10900.000
# max           9390.000 9400.000 15990.000 7700.000 19499.000     15995.000
#
# make_model             Renault Duster Renault Espace                      \
# age                             0.000          0.000
# body_type  Transporter       Off-Road        Compact     Coupe    Sedans
# count           11.000         34.000          3.000     1.000     3.000
# mean          7376.364      13230.176      38830.000 34140.000 45478.667
# std            876.838       1622.405       4855.070       NaN  3924.125
# min           5900.000      10850.000      33500.000 34140.000 41043.000
# 25%           6745.000      11925.000      36745.000 34140.000 43969.000
# 50%           7500.000      13189.000      39990.000 34140.000 46895.000
# 75%           8045.000      14399.000      41495.000 34140.000 47696.500
# max           8490.000      16033.000      43000.000 34140.000 48498.000
#
# make_model                                                                    \
# age                                                1.000
# body_type  Station wagon Transporter       Van     Coupe  Off-Road    Sedans
# count             12.000       1.000   237.000     1.000     2.000    13.000
# mean           44100.833   32700.000 40039.063 26994.000 27850.000 29090.462
# std             4100.369         NaN  8047.113       NaN     0.000  3321.812
# min            37900.000   32700.000 24200.000 26994.000 27850.000 25490.000
# 25%            42490.000   32700.000 32975.000 26994.000 27850.000 25995.000
# 50%            42835.000   32700.000 38950.000 26994.000 27850.000 28990.000
# 75%            44215.000   32700.000 45890.000 26994.000 27850.000 30900.000
# max            52990.000   32700.000 68320.000 26994.000 27850.000 36900.000
#
# make_model                                                                    \
# age                                                2.000
# body_type  Station wagon Transporter       Van   Compact  Off-Road    Sedans
# count             14.000       5.000   207.000     1.000     5.000     3.000
# mean           34301.429   29297.800 31947.841 23990.000 27100.000 23863.333
# std             3864.125    1306.587  4072.970       NaN  4103.657   109.697
# min            28990.000   27990.000 23099.000 23990.000 22500.000 23800.000
# 25%            30230.000   27999.000 29385.000 23990.000 24900.000 23800.000
# 50%            35370.000   29500.000 31900.000 23990.000 25700.000 23800.000
# 75%            37730.000   30000.000 34990.000 23990.000 29500.000 23895.000
# max            39990.000   31000.000 38990.000 23990.000 32900.000 23990.000
#
# make_model                                                                    \
# age                                                3.000
# body_type  Station wagon Transporter       Van   Compact  Off-Road    Sedans
# count             13.000       9.000   134.000     2.000     1.000     2.000
# mean           27046.846   23861.000 26574.478 19900.000 14900.000 22449.500
# std             5245.900    3464.582  3427.863  2828.427       NaN  4879.744
# min            19450.000   19450.000 14600.000 17900.000 14900.000 18999.000
# 25%            23400.000   21000.000 24982.500 18900.000 14900.000 20724.250
# 50%            27500.000   25000.000 25490.000 19900.000 14900.000 22449.500
# 75%            30980.000   27000.000 28500.000 20900.000 14900.000 24174.750
# max            33900.000   28300.000 33800.000 21900.000 14900.000 25900.000
#
# make_model
# age
# body_type  Station wagon Transporter       Van
# count             52.000      37.000   199.000
# mean           21626.827   21124.297 22132.623
# std             2862.987    3279.229  3216.032
# min            16900.000   14999.000 12614.000
# 25%            19950.000   19000.000 19900.000
# 50%            20455.000   20500.000 22222.000
# 75%            23605.000   24200.000 24650.000
# max            27500.000   30000.000 27900.000

# %%
fill_with(df, "make_model", "age", "body_type", "mode")
# Out:
# Number of NaN :  0
# ------------------
# Sedans           8015
# Station wagon    3668
# Compact          3242
# Van               817
# Transporter        88
# Off-Road           56
# Coupe              25
# Convertible         8
# Name: body_type, dtype: int64

# %% [markdown]
# ## - Type

# %%
info('Type')
# Out:
# Column Name    :  Type
# --------------------------------
# Number of Nulls       :  2
# Percentage of Nulls   :  % 0.01
# Number of Uniques     :  5
# --------------------------------
#
# Used              11096
# New                1650
# Pre-registered     1364
# Employee's car     1011
# Demonstration       796
# NaN                   2
# Name: Type, dtype: int64

# %%
fill_with(df, "make_model", "age", "Type", "mode")
# Out:
# Number of NaN :  0
# ------------------
# Used              11097
# New                1651
# Pre-registered     1364
# Employee's car     1011
# Demonstration       796
# Name: Type, dtype: int64

# %% [markdown]
# ## - Previous Owners

# %%
info('Previous Owners')
# Out:
# Column Name    :  Previous Owners
# --------------------------------
# Number of Nulls       :  6640
# Percentage of Nulls   :  % 41.71
# Number of Uniques     :  5
# --------------------------------
#
# 1.000    8294
# NaN      6640
# 2.000     778
# 0.000     188
# 3.000      17
# 4.000       2
# Name: Previous Owners, dtype: int64

# %%
df.groupby(['make_model', 'body_type', 'age', 'Previous Owners']).price.describe()
# Out:
#                                                  count      mean      std  \
# make_model     body_type age   Previous Owners
# Audi A1        Compact   0.000 0.000            16.000 22445.562 1877.170
#                                1.000            81.000 23396.506 3380.448
#                                2.000             1.000 21760.000      NaN
#                          1.000 1.000           195.000 18108.738 2381.809
#                                2.000             7.000 19319.714 2516.064
# ...                                                ...       ...      ...
# Renault Espace Van       2.000 1.000            30.000 25796.333 3739.392
#                                2.000            37.000 26019.811 2071.906
#                          3.000 0.000             1.000 24900.000      NaN
#                                1.000           103.000 21590.417 3555.577
#                                2.000            14.000 23641.000 2699.715
#
#                                                      min       25%       50%  \
# make_model     body_type age   Previous Owners
# Audi A1        Compact   0.000 0.000           19490.000 22174.750 22400.000
#                                1.000           14900.000 21330.000 22900.000
#                                2.000           21760.000 21760.000 21760.000
#                          1.000 1.000           13980.000 16430.000 16940.000
#                                2.000           16960.000 16980.000 18470.000
# ...                                                  ...       ...       ...
# Renault Espace Van       2.000 1.000           16950.000 23990.000 26245.000
#                                2.000           19450.000 25490.000 25490.000
#                          3.000 0.000           24900.000 24900.000 24900.000
#                                1.000           12614.000 18995.000 21900.000
#                                2.000           19490.000 21474.250 23495.000
#
#                                                      75%       max
# make_model     body_type age   Previous Owners
# Audi A1        Compact   0.000 0.000           22480.000 28650.000
#                                1.000           25800.000 29179.000
#                                2.000           21760.000 21760.000
#                          1.000 1.000           19989.000 23829.000
#                                2.000           21949.000 21950.000
# ...                                                  ...       ...
# Renault Espace Van       2.000 1.000           28800.000 31775.000
#                                2.000           25490.000 33285.000
#                          3.000 0.000           24900.000 24900.000
#                                1.000           24550.000 27900.000
#                                2.000           25933.750 27900.000
#
# [211 rows x 8 columns]

# %%
df.groupby(['make_model', 'age', 'Previous Owners']).km.describe()
# Out:
#                                        count      mean       std       min  \
# make_model     age   Previous Owners
# Audi A1        0.000 0.000            45.000   899.268   770.705     0.000
#                      1.000           239.000  3068.471  3460.864     1.000
#                      2.000             1.000  3000.000       NaN  3000.000
#                1.000 0.000             1.000 15000.000       NaN 15000.000
#                      1.000           496.000 13785.156  8108.001    20.000
# ...                                      ...       ...       ...       ...
# Renault Espace 3.000 0.000             1.000 91883.000       NaN 91883.000
#                      1.000           118.000 79365.805 36296.880  3532.000
#                      2.000            20.000 55316.250 27356.183  7300.000
#                      3.000             1.000 40000.000       NaN 40000.000
#                      4.000             1.000 57000.000       NaN 57000.000
#
#                                            25%       50%       75%        max
# make_model     age   Previous Owners
# Audi A1        0.000 0.000              10.000  1519.261  1519.261   2190.536
#                      1.000              20.000  2500.000  5000.000  18000.000
#                      2.000            3000.000  3000.000  3000.000   3000.000
#                1.000 0.000           15000.000 15000.000 15000.000  15000.000
#                      1.000            6898.000 11317.500 21054.000  35500.000
# ...                                        ...       ...       ...        ...
# Renault Espace 3.000 0.000           91883.000 91883.000 91883.000  91883.000
#                      1.000           55000.000 76475.000 98375.750 197414.000
#                      2.000           42536.750 51972.500 64921.250 148000.000
#                      3.000           40000.000 40000.000 40000.000  40000.000
#                      4.000           57000.000 57000.000 57000.000  57000.000
#
# [91 rows x 8 columns]

# %%
fill_with(df, "make_model", "age", "Previous Owners", "ffill")
# Out:
# Number of NaN :  0
# ------------------
# 1.000    14154
# 2.000     1171
# 0.000      563
# 3.000       29
# 4.000        2
# Name: Previous Owners, dtype: int64

# %% [markdown]
# ## - Warranty

# %%
info('Warranty')
# Out:
# Column Name    :  Warranty
# --------------------------------
# Number of Nulls       :  11066
# Percentage of Nulls   :  % 69.51
# Number of Uniques     :  41
# --------------------------------
#
# NaN       11066
# 12.000     2594
# 24.000     1118
# 60.000      401
# 36.000      279
# 48.000      149
# 6.000       125
# 72.000       59
# 3.000        33
# 23.000       11
# 18.000       10
# 20.000        7
# 25.000        6
# 2.000         5
# 50.000        4
# 26.000        4
# 16.000        4
# 4.000         3
# 1.000         3
# 19.000        3
# 34.000        3
# 13.000        3
# 28.000        2
# 22.000        2
# 14.000        2
# 11.000        2
# 46.000        2
# 21.000        2
# 9.000         2
# 17.000        2
# 45.000        2
# 33.000        1
# 40.000        1
# 65.000        1
# 10.000        1
# 15.000        1
# 7.000         1
# 8.000         1
# 56.000        1
# 49.000        1
# 47.000        1
# 30.000        1
# Name: Warranty, dtype: int64

# %%
df.groupby(["Warranty"])['price'].describe(include='O')
# Out:
#             count      mean       std       min       25%       50%       75%  \
# Warranty
# 1.000       3.000 18383.333  4269.292 13455.000 17100.000 20745.000 20847.500
# 2.000       5.000 14604.000  2709.369 10750.000 12990.000 15290.000 16990.000
# 3.000      33.000 16278.212  8782.362  5800.000  8900.000 14950.000 17990.000
# 4.000       3.000 19666.667  7922.331 11200.000 16050.000 20900.000 23900.000
# 6.000     125.000 14608.704  6033.523  5900.000  8790.000 13990.000 18900.000
# 7.000       1.000 21480.000       NaN 21480.000 21480.000 21480.000 21480.000
# 8.000       1.000 17500.000       NaN 17500.000 17500.000 17500.000 17500.000
# 9.000       2.000 10797.500     0.707 10797.000 10797.250 10797.500 10797.750
# 10.000      1.000 19990.000       NaN 19990.000 19990.000 19990.000 19990.000
# 11.000      2.000 20897.000  8341.032 14999.000 17948.000 20897.000 23846.000
# 12.000   2594.000 15659.427  5810.191  5250.000 11410.000 14950.000 18990.000
# 13.000      3.000 16746.667  6298.137  9500.000 14670.000 19840.000 20370.000
# 14.000      2.000 24990.000  1414.214 23990.000 24490.000 24990.000 25490.000
# 15.000      1.000 21450.000       NaN 21450.000 21450.000 21450.000 21450.000
# 16.000      4.000 24730.750 11677.217 10893.000 18960.750 24570.000 30340.000
# 17.000      2.000  8944.500  1761.403  7699.000  8321.750  8944.500  9567.250
# 18.000     10.000 23056.900  4335.447 16999.000 20625.000 21997.500 23972.500
# 19.000      3.000 24665.333  2798.107 21450.000 23724.000 25998.000 26273.000
# 20.000      7.000 21154.143  9026.598 11999.000 15470.000 18750.000 25745.000
# 21.000      2.000 26220.000   325.269 25990.000 26105.000 26220.000 26335.000
# 22.000      2.000 20175.000   813.173 19600.000 19887.500 20175.000 20462.500
# 23.000     11.000 15376.000  7937.432 10990.000 11240.000 12170.000 14783.000
# 24.000   1118.000 20045.742  8018.788  6900.000 14703.500 19850.000 23999.000
# 25.000      6.000 20946.333  8591.413 11890.000 15842.500 20625.000 21500.000
# 26.000      4.000 26869.000 11177.217 15840.000 17940.000 27569.000 36498.000
# 28.000      2.000 17925.000  4277.996 14900.000 16412.500 17925.000 19437.500
# 30.000      1.000 36400.000       NaN 36400.000 36400.000 36400.000 36400.000
# 33.000      1.000 23299.000       NaN 23299.000 23299.000 23299.000 23299.000
# 34.000      3.000 25694.333  3283.027 23099.000 23849.000 24599.000 26992.000
# 36.000    279.000 21487.892  5386.531  9400.000 16820.000 20850.000 25435.000
# 40.000      1.000 22500.000       NaN 22500.000 22500.000 22500.000 22500.000
# 45.000      2.000 29200.000 12374.369 20450.000 24825.000 29200.000 33575.000
# 46.000      2.000 24490.000 12034.957 15980.000 20235.000 24490.000 28745.000
# 47.000      1.000 16370.000       NaN 16370.000 16370.000 16370.000 16370.000
# 48.000    149.000 20929.262  8421.026  9300.000 15870.000 20500.000 24500.000
# 49.000      1.000 16270.000       NaN 16270.000 16270.000 16270.000 16270.000
# 50.000      4.000 18837.500  2166.308 16370.000 17945.000 18670.000 19562.500
# 56.000      1.000 21760.000       NaN 21760.000 21760.000 21760.000 21760.000
# 60.000    401.000 16980.112  7468.114  6450.000 10980.000 15989.000 20980.000
# 65.000      1.000 11490.000       NaN 11490.000 11490.000 11490.000 11490.000
# 72.000     59.000 27362.288  9258.446 10970.000 17420.000 29475.000 34190.000
#
#                max
# Warranty
# 1.000    20950.000
# 2.000    17000.000
# 3.000    39990.000
# 4.000    26900.000
# 6.000    33800.000
# 7.000    21480.000
# 8.000    17500.000
# 9.000    10798.000
# 10.000   19990.000
# 11.000   26795.000
# 12.000   51900.000
# 13.000   20900.000
# 14.000   25990.000
# 15.000   21450.000
# 16.000   38890.000
# 17.000   10190.000
# 18.000   30800.000
# 19.000   26548.000
# 20.000   34900.000
# 21.000   26450.000
# 22.000   20750.000
# 23.000   37600.000
# 24.000   68320.000
# 25.000   36498.000
# 26.000   36498.000
# 28.000   20950.000
# 30.000   36400.000
# 33.000   23299.000
# 34.000   29385.000
# 36.000   39990.000
# 40.000   22500.000
# 45.000   37950.000
# 46.000   33000.000
# 47.000   16370.000
# 48.000   47990.000
# 49.000   16270.000
# 50.000   21640.000
# 56.000   21760.000
# 60.000   46890.000
# 65.000   11490.000
# 72.000   42475.000

# %%
df.drop("Warranty", axis=1, inplace=True)

# It has too much null values and there is no relation between Warranty and Price

# %% [markdown]
# ## - Nr. of Doors

# %%
info('Nr. of Doors')
# Out:
# Column Name    :  Nr. of Doors
# --------------------------------
# Number of Nulls       :  212
# Percentage of Nulls   :  % 1.33
# Number of Uniques     :  6
# --------------------------------
#
# 5.000    11575
# 4.000     3079
# 3.000      832
# 2.000      219
# NaN        212
# 1.000        1
# 7.000        1
# Name: Nr. of Doors, dtype: int64

# %%
fill_with(df, "make_model", "body_type", "Nr. of Doors", "mode")
# Out:
# Number of NaN :  0
# ------------------
# 5.000    11787
# 4.000     3079
# 3.000      832
# 2.000      219
# 1.000        1
# 7.000        1
# Name: Nr. of Doors, dtype: int64

# %% [markdown]
# ## - Nr. of Seats

# %%
info("Nr. of Seats")
# Out:
# Column Name    :  Nr. of Seats
# --------------------------------
# Number of Nulls       :  977
# Percentage of Nulls   :  % 6.14
# Number of Uniques     :  6
# --------------------------------
#
# 5.000    13336
# 4.000     1125
# NaN        977
# 7.000      362
# 2.000      116
# 6.000        2
# 3.000        1
# Name: Nr. of Seats, dtype: int64

# %%
fill_with(df, "make_model", "body_type", "Nr. of Seats", "mode")
# Out:
# Number of NaN :  0
# ------------------
# 5.000    14308
# 4.000     1127
# 7.000      362
# 2.000      119
# 6.000        2
# 3.000        1
# Name: Nr. of Seats, dtype: int64

# %% [markdown]
# ## - Gearing_Type

# %%
info('Gearing Type')
# Out:
# Column Name    :  Gearing Type
# --------------------------------
# Number of Nulls       :  0
# Percentage of Nulls   :  % 0.0
# Number of Uniques     :  3
# --------------------------------
#
# Manual            8153
# Automatic         7297
# Semi-automatic     469
# Name: Gearing Type, dtype: int64

# %% [markdown]
# ## - Cylinders

# %%
info('Cylinders')
# Out:
# Column Name    :  Cylinders
# --------------------------------
# Number of Nulls       :  5680
# Percentage of Nulls   :  % 35.68
# Number of Uniques     :  7
# --------------------------------
#
# 4.000    8105
# NaN      5680
# 3.000    2104
# 5.000      22
# 6.000       3
# 8.000       2
# 2.000       2
# 1.000       1
# Name: Cylinders, dtype: int64

# %%
fill_with(df, "make_model", "Weight_kg", "Cylinders", "ffill")
# Out:
# Number of NaN :  0
# ------------------
# 4.000    12567
# 3.000     3311
# 5.000       26
# 8.000        5
# 2.000        5
# 6.000        3
# 1.000        2
# Name: Cylinders, dtype: int64

# %%
df.drop('Cylinders', axis=1, inplace=True)  

# It has similar values with kW, but more null values,so we don't need this column.

# %% [markdown]
# ## - Drive_Chain

# %%
info('Drive chain')
# Out:
# Column Name    :  Drive chain
# --------------------------------
# Number of Nulls       :  6858
# Percentage of Nulls   :  % 43.08
# Number of Uniques     :  3
# --------------------------------
#
# front    8886
# NaN      6858
# 4WD       171
# rear        4
# Name: Drive chain, dtype: int64

# %%
df.groupby(["make_model", "body_type", "Drive chain"]).price.describe()
# Out:
#                                             count      mean       std  \
# make_model     body_type     Drive chain
# Audi A1        Compact       4WD            2.000 14790.000  1258.650
#                              front        685.000 20008.223  4511.348
#                Sedans        4WD            1.000 15450.000       NaN
#                              front        989.000 19133.794  4441.969
#                Station wagon front         18.000 16681.111  2493.673
#                Van           front          1.000 29000.000       NaN
# Audi A2        Off-Road      front          1.000 28200.000       NaN
# Audi A3        Compact       4WD            1.000 67600.000       NaN
#                              front        156.000 18839.365  6078.743
#                Convertible   4WD            1.000 56100.000       NaN
#                              front          3.000 20897.667 10003.500
#                Coupe         front          3.000 17996.667  1005.004
#                Sedans        4WD           17.000 32913.765 20353.178
#                              front       1713.000 21223.413  3546.978
#                Station wagon front        133.000 21165.647  3552.001
# Opel Astra     Compact       front        104.000 14802.837  5080.910
#                Off-Road      front          1.000 18590.000       NaN
#                Sedans        4WD            2.000 13075.000  3641.600
#                              front        545.000 16417.306  4596.469
#                Station wagon front        696.000 16289.017  5321.904
# Opel Corsa     Compact       front        640.000 12487.231  3014.209
#                Coupe         front          7.000  8407.143  1342.395
#                Sedans        front        517.000 10515.445  2691.045
#                Transporter   front          6.000  7175.000  2073.343
# Opel Insignia  Compact       front         10.000 28355.000 12606.283
#                Off-Road      4WD            5.000 28232.800  8948.569
#                              front          1.000 31505.000       NaN
#                Sedans        4WD           26.000 34139.346  6543.818
#                              front        505.000 21675.178  7462.771
#                              rear           1.000 18990.000       NaN
#                Station wagon 4WD           63.000 27784.540 10677.083
#                              front        892.000 22489.775  7656.689
#                              rear           2.000 15925.000  4277.996
#                Van           front          1.000 20980.000       NaN
# Renault Clio   Compact       4WD            1.000  9680.000       NaN
#                              front        213.000 12359.113  4342.140
#                Coupe         front          1.000 17990.000       NaN
#                Off-Road      front          1.000 17990.000       NaN
#                Sedans        4WD            9.000 23021.000     0.000
#                              front        416.000 11610.428  3872.653
#                              rear           1.000 10490.000       NaN
#                Station wagon 4WD            1.000 15798.000       NaN
#                              front        155.000 10983.510  2589.221
#                Transporter   front          8.000  8546.125  1346.641
#                Van           front          1.000  9400.000       NaN
# Renault Duster Off-Road      4WD            2.000 11425.000   813.173
# Renault Espace Compact       front          1.000 21900.000       NaN
#                Off-Road      front          3.000 21033.333  5547.372
#                Sedans        front          5.000 27778.000  3676.740
#                Station wagon 4WD            1.000 35990.000       NaN
#                              front         70.000 26825.214  9096.536
#                Transporter   4WD            1.000 30000.000       NaN
#                              front          6.000 23258.167  5973.317
#                Van           4WD           38.000 38150.763 10013.779
#                              front        379.000 31525.164  8343.192
#
#                                                min       25%       50%  \
# make_model     body_type     Drive chain
# Audi A1        Compact       4WD         13900.000 14345.000 14790.000
#                              front        9950.000 16430.000 19890.000
#                Sedans        4WD         15450.000 15450.000 15450.000
#                              front       10000.000 15838.000 18500.000
#                Station wagon front       12950.000 15000.000 16356.000
#                Van           front       29000.000 29000.000 29000.000
# Audi A2        Off-Road      front       28200.000 28200.000 28200.000
# Audi A3        Compact       4WD         67600.000 67600.000 67600.000
#                              front       13100.000 13910.000 17724.500
#                Convertible   4WD         56100.000 56100.000 56100.000
#                              front       10893.000 15896.500 20900.000
#                Coupe         front       16990.000 17495.000 18000.000
#                Sedans        4WD         13780.000 16999.000 22499.000
#                              front       10990.000 18700.000 21490.000
#                Station wagon front       13250.000 18480.000 21450.000
# Opel Astra     Compact       front        8450.000 11955.000 12955.000
#                Off-Road      front       18590.000 18590.000 18590.000
#                Sedans        4WD         10500.000 11787.500 13075.000
#                              front        8860.000 12900.000 15890.000
#                Station wagon front        6690.000 12250.000 15890.000
# Opel Corsa     Compact       front        4990.000 10250.000 12942.500
#                Coupe         front        6900.000  7500.000  8500.000
#                Sedans        front        5970.000  8500.000  9900.000
#                Transporter   front        5250.000  5487.500  6525.000
# Opel Insignia  Compact       front       10350.000 16500.000 35845.000
#                Off-Road      4WD         12750.000 28500.000 32345.000
#                              front       31505.000 31505.000 31505.000
#                Sedans        4WD         17480.000 32325.500 34991.000
#                              front        9650.000 16690.000 20400.000
#                              rear        18990.000 18990.000 18990.000
#                Station wagon 4WD         11480.000 16940.000 34550.000
#                              front        8990.000 16182.000 21385.000
#                              rear        12900.000 14412.500 15925.000
#                Van           front       20980.000 20980.000 20980.000
# Renault Clio   Compact       4WD          9680.000  9680.000  9680.000
#                              front        6900.000  8750.000 11190.000
#                Coupe         front       17990.000 17990.000 17990.000
#                Off-Road      front       17990.000 17990.000 17990.000
#                Sedans        4WD         23021.000 23021.000 23021.000
#                              front        5445.000  9480.000 10690.000
#                              rear        10490.000 10490.000 10490.000
#                Station wagon 4WD         15798.000 15798.000 15798.000
#                              front        5900.000  9615.000 10450.000
#                Transporter   front        6900.000  7600.000  8531.000
#                Van           front        9400.000  9400.000  9400.000
# Renault Duster Off-Road      4WD         10850.000 11137.500 11425.000
# Renault Espace Compact       front       21900.000 21900.000 21900.000
#                Off-Road      front       14900.000 18700.000 22500.000
#                Sedans        front       23800.000 23800.000 29490.000
#                Station wagon 4WD         35990.000 35990.000 35990.000
#                              front       17900.000 20455.000 21950.000
#                Transporter   4WD         30000.000 30000.000 30000.000
#                              front       17000.000 19262.500 21500.000
#                Van           4WD         24950.000 31900.000 34200.000
#                              front       12614.000 25050.000 31360.000
#
#                                                75%       max
# make_model     body_type     Drive chain
# Audi A1        Compact       4WD         15235.000 15680.000
#                              front       22690.000 31990.000
#                Sedans        4WD         15450.000 15450.000
#                              front       21999.000 32000.000
#                Station wagon front       17300.000 21450.000
#                Van           front       29000.000 29000.000
# Audi A2        Off-Road      front       28200.000 28200.000
# Audi A3        Compact       4WD         67600.000 67600.000
#                              front       20810.000 41495.000
#                Convertible   4WD         56100.000 56100.000
#                              front       25900.000 30900.000
#                Coupe         front       18500.000 19000.000
#                Sedans        4WD         51999.000 74600.000
#                              front       23800.000 34738.000
#                Station wagon front       24200.000 27400.000
# Opel Astra     Compact       front       16344.000 39433.000
#                Off-Road      front       18590.000 18590.000
#                Sedans        4WD         14362.500 15650.000
#                              front       18450.000 32950.000
#                Station wagon front       18492.500 34900.000
# Opel Corsa     Compact       front       14790.000 18622.000
#                Coupe         front        8750.000 10950.000
#                Sedans        front       11690.000 18490.000
#                Transporter   front        9062.500  9700.000
# Opel Insignia  Compact       front       38365.000 39990.000
#                Off-Road      4WD         32793.000 34776.000
#                              front       31505.000 31505.000
#                Sedans        4WD         37356.250 48950.000
#                              front       25464.000 49350.000
#                              rear        18990.000 18990.000
#                Station wagon 4WD         36970.000 42475.000
#                              front       27174.750 52120.000
#                              rear        17437.500 18950.000
#                Van           front       20980.000 20980.000
# Renault Clio   Compact       4WD          9680.000  9680.000
#                              front       15485.000 29740.000
#                Coupe         front       17990.000 17990.000
#                Off-Road      front       17990.000 17990.000
#                Sedans        4WD         23021.000 23021.000
#                              front       12960.000 29850.000
#                              rear        10490.000 10490.000
#                Station wagon 4WD         15798.000 15798.000
#                              front       11500.000 20680.000
#                Transporter   front        9417.750 10460.000
#                Van           front        9400.000  9400.000
# Renault Duster Off-Road      4WD         11712.500 12000.000
# Renault Espace Compact       front       21900.000 21900.000
#                Off-Road      front       24100.000 25700.000
#                Sedans        front       30900.000 30900.000
#                Station wagon 4WD         35990.000 35990.000
#                              front       30732.500 52990.000
#                Transporter   4WD         30000.000 30000.000
#                              front       26624.250 32700.000
#                Van           4WD         45747.000 57990.000
#                              front       36151.000 68320.000

# %%
fill_with(df, 'body_type', 'make_model', 'Drive chain', 'mode')
# Out:
# Number of NaN :  0
# ------------------
# front    15708
# 4WD        207
# rear         4
# Name: Drive chain, dtype: int64

# %% [markdown]
# ## - Fuel

# %%
info('Fuel')
# Out:
# Column Name    :  Fuel
# --------------------------------
# Number of Nulls       :  0
# Percentage of Nulls   :  % 0.0
# Number of Uniques     :  4
# --------------------------------
#
# Benzine     8551
# Diesel      7299
# LPG/CNG       64
# Electric       5
# Name: Fuel, dtype: int64

# %% [markdown]
# ## - Emission_Class

# %%
info('Emission Class')
# Out:
# Column Name    :  Emission Class
# --------------------------------
# Number of Nulls       :  3628
# Percentage of Nulls   :  % 22.79
# Number of Uniques     :  6
# --------------------------------
#
# Euro6          10139
# NaN             3628
# Euro6d-TEMP     1845
# Euro6c           127
# Euro5             78
# Euro6d            62
# Euro4             40
# Name: Emission Class, dtype: int64

# %%
df.groupby(["make_model", "age", "Fuel", "Emission Class"]).price.describe()
# Out:
#                                               count      mean      std  \
# make_model     age   Fuel    Emission Class
# Audi A1        0.000 Benzine Euro6          266.000 24373.947 3245.464
#                              Euro6d           5.000 21510.000  356.371
#                              Euro6d-TEMP    264.000 23566.080 3664.202
#                      Diesel  Euro6            4.000 19370.000 1181.891
#                1.000 Benzine Euro5            3.000 17862.667 1840.593
# ...                                             ...       ...      ...
# Renault Espace 3.000 Diesel  Euro5            1.000 24900.000      NaN
#                              Euro6          197.000 21449.437 3293.226
#                              Euro6c           1.000 17000.000      NaN
#                              Euro6d           1.000 17900.000      NaN
#                              Euro6d-TEMP      3.000 22496.667 1320.997
#
#                                                   min       25%       50%  \
# make_model     age   Fuel    Emission Class
# Audi A1        0.000 Benzine Euro6          15550.000 21800.000 24070.000
#                              Euro6d         20990.000 21490.000 21490.000
#                              Euro6d-TEMP    16985.000 20697.500 22490.000
#                      Diesel  Euro6          17900.000 18717.500 19495.000
#                1.000 Benzine Euro5          16800.000 16800.000 16800.000
# ...                                               ...       ...       ...
# Renault Espace 3.000 Diesel  Euro5          24900.000 24900.000 24900.000
#                              Euro6          12614.000 19100.000 20900.000
#                              Euro6c         17000.000 17000.000 17000.000
#                              Euro6d         17900.000 17900.000 17900.000
#                              Euro6d-TEMP    21000.000 21995.000 22990.000
#
#                                                   75%       max
# make_model     age   Fuel    Emission Class
# Audi A1        0.000 Benzine Euro6          27380.000 29197.000
#                              Euro6d         21590.000 21990.000
#                              Euro6d-TEMP    26920.000 37900.000
#                      Diesel  Euro6          20147.500 20590.000
#                1.000 Benzine Euro5          18394.000 19988.000
# ...                                               ...       ...
# Renault Espace 3.000 Diesel  Euro5          24900.000 24900.000
#                              Euro6          23990.000 30000.000
#                              Euro6c         17000.000 17000.000
#                              Euro6d         17900.000 17900.000
#                              Euro6d-TEMP    23245.000 23500.000
#
# [181 rows x 8 columns]

# %%
df.drop("Emission Class", axis=1, inplace=True)

# %% [markdown]
# ## - comfort_convenience

# %%
info('comfort_convenience')
# Out:
# Column Name    :  comfort_convenience
# --------------------------------
# Number of Nulls       :  920
# Percentage of Nulls   :  % 5.78
# Number of Uniques     :  6198
# --------------------------------
#
# NaN                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  920
# Air conditioning,Electrical side mirrors,Hill Holder,Power windows                                                                                                                                                                                                                                                                                                                                                                                                                                   216
# Air conditioning,Electrical side mirrors,Power windows                                                                                                                                                                                                                                                                                                                                                                                                                                               134
# Air conditioning,Power windows                                                                                                                                                                                                                                                                                                                                                                                                                                                                       130
# Air conditioning,Armrest,Automatic climate control,Cruise control,Electrical side mirrors,Leather steering wheel,Light sensor,Lumbar support,Multi-function steering wheel,Navigation system,Park Distance Control,Parking assist system sensors front,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Start-stop system                                                                                                                                                   105
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ...
# Air conditioning,Cruise control,Electrical side mirrors,Hill Holder,Leather steering wheel,Light sensor,Multi-function steering wheel,Navigation system,Park Distance Control,Parking assist system sensors rear,Power windows,Rain sensor,Split rear seats,Start-stop system,Tinted windows                                                                                                                                                                                                           1
# Air conditioning,Armrest,Automatic climate control,Cruise control,Electrical side mirrors,Heated steering wheel,Hill Holder,Leather steering wheel,Light sensor,Lumbar support,Multi-function steering wheel,Navigation system,Park Distance Control,Parking assist system camera,Parking assist system sensors front,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Sunroof                                                                                                1
# Air conditioning,Armrest,Cruise control,Electrical side mirrors,Heated steering wheel,Hill Holder,Leather steering wheel,Light sensor,Multi-function steering wheel,Park Distance Control,Parking assist system camera,Parking assist system sensors front,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Split rear seats,Start-stop system,Tinted windows                                                                                                                 1
# Air conditioning,Automatic climate control,Cruise control,Electrical side mirrors,Leather steering wheel,Light sensor,Multi-function steering wheel,Park Distance Control,Parking assist system sensors front,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating                                                                                                                                                                                                                1
# Air conditioning,Automatic climate control,Cruise control,Electrically heated windshield,Electrical side mirrors,Electric tailgate,Heads-up display,Heated steering wheel,Hill Holder,Keyless central door lock,Leather steering wheel,Light sensor,Lumbar support,Navigation system,Park Distance Control,Parking assist system camera,Parking assist system self-steering,Parking assist system sensors front,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Sunroof      1
# Name: comfort_convenience, Length: 6199, dtype: int64

# %%
fill_with(df,'make_model', 'body_type', 'comfort_convenience', 'mode')
# Out:
# Number of NaN :  0
# ------------------
# Air conditioning,Electrical side mirrors,Hill Holder,Power windows                                                                                                                                                                                                                                                                                                                                                                                                                                   388
# Air conditioning,Armrest,Automatic climate control,Cruise control,Electrical side mirrors,Leather steering wheel,Light sensor,Lumbar support,Multi-function steering wheel,Navigation system,Park Distance Control,Parking assist system sensors front,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Start-stop system                                                                                                                                                   187
# Air conditioning,Armrest,Automatic climate control,Cruise control,Electrically adjustable seats,Electrical side mirrors,Electric tailgate,Heated steering wheel,Hill Holder,Keyless central door lock,Leather steering wheel,Light sensor,Lumbar support,Multi-function steering wheel,Navigation system,Park Distance Control,Parking assist system camera,Parking assist system sensors front,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Start-stop system          161
# Air conditioning,Automatic climate control,Cruise control,Multi-function steering wheel,Park Distance Control,Power windows                                                                                                                                                                                                                                                                                                                                                                          160
# Air conditioning,Electrical side mirrors,Power windows                                                                                                                                                                                                                                                                                                                                                                                                                                               134
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ...
# Air conditioning,Cruise control,Electrical side mirrors,Multi-function steering wheel,Park Distance Control,Parking assist system sensors front,Parking assist system sensors rear,Power windows,Start-stop system                                                                                                                                                                                                                                                                                     1
# Air conditioning,Armrest,Cruise control,Electrical side mirrors,Heated steering wheel,Hill Holder,Leather steering wheel,Light sensor,Multi-function steering wheel,Park Distance Control,Parking assist system camera,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Split rear seats,Start-stop system,Sunroof,Tinted windows                                                                                                                                             1
# Air conditioning,Armrest,Cruise control,Hill Holder,Leather steering wheel,Multi-function steering wheel,Park Distance Control,Parking assist system sensors front,Parking assist system sensors rear,Power windows                                                                                                                                                                                                                                                                                    1
# Air conditioning,Armrest,Automatic climate control,Cruise control,Electrical side mirrors,Leather steering wheel,Multi-function steering wheel,Power windows,Rain sensor,Start-stop system,Tinted windows                                                                                                                                                                                                                                                                                              1
# Air conditioning,Automatic climate control,Cruise control,Electrically heated windshield,Electrical side mirrors,Electric tailgate,Heads-up display,Heated steering wheel,Hill Holder,Keyless central door lock,Leather steering wheel,Light sensor,Lumbar support,Navigation system,Park Distance Control,Parking assist system camera,Parking assist system self-steering,Parking assist system sensors front,Parking assist system sensors rear,Power windows,Rain sensor,Seat heating,Sunroof      1
# Name: comfort_convenience, Length: 6198, dtype: int64

# %% [markdown]
# ## - entertainment_media

# %%
info('entertainment_media')
# Out:
# Column Name    :  entertainment_media
# --------------------------------
# Number of Nulls       :  1374
# Percentage of Nulls   :  % 8.63
# Number of Uniques     :  346
# --------------------------------
#
# NaN                                                                                                 1374
# Bluetooth,Hands-free equipment,On-board computer,Radio,USB                                          1282
# Bluetooth,Hands-free equipment,MP3,On-board computer,Radio,USB                                       982
# Bluetooth,CD player,Hands-free equipment,MP3,On-board computer,Radio,USB                             783
# On-board computer,Radio                                                                              487
#                                                                                                     ...
# Bluetooth,CD player,Digital radio,Hands-free equipment,Radio                                           1
# CD player,Hands-free equipment,MP3,Radio,USB                                                           1
# MP3,Radio,Sound system,USB                                                                             1
# Bluetooth,MP3,On-board computer,Radio,Television,USB                                                   1
# Bluetooth,CD player,Hands-free equipment,MP3,On-board computer,Radio,Sound system,Television,USB       1
# Name: entertainment_media, Length: 347, dtype: int64

# %%
fill_with(df, 'make_model', 'body_type', 'entertainment_media', 'mode')
# Out:
# Number of NaN :  0
# ------------------
# Bluetooth,Hands-free equipment,On-board computer,Radio,USB                      1742
# Bluetooth,Hands-free equipment,MP3,On-board computer,Radio,USB                  1117
# Bluetooth,CD player,Hands-free equipment,MP3,On-board computer,Radio,USB        1027
# On-board computer                                                                611
# Radio                                                                            558
#                                                                                 ...
# Bluetooth,CD player,MP3                                                            1
# CD player,USB                                                                      1
# Bluetooth,CD player,Digital radio,Radio,USB                                        1
# Bluetooth,CD player,Digital radio,MP3,On-board computer,Radio,Television,USB       1
# Hands-free equipment,On-board computer,Radio,Sound system                          1
# Name: entertainment_media, Length: 346, dtype: int64

# %% [markdown]
# ## - Extras

# %%
info('Extras')
# Out:
# Column Name    :  Extras
# --------------------------------
# Number of Nulls       :  2962
# Percentage of Nulls   :  % 18.61
# Number of Uniques     :  659
# --------------------------------
#
# Alloy wheels                                                                                               3245
# NaN                                                                                                        2962
# Alloy wheels,Touch screen                                                                                   697
# Alloy wheels,Voice Control                                                                                  577
# Alloy wheels,Touch screen,Voice Control                                                                     541
#                                                                                                            ...
# Alloy wheels,Catalytic Converter,Shift paddles,Sport package,Sport seats,Sport suspension,Voice Control       1
# Alloy wheels,Catalytic Converter,Roof rack,Sport package,Sport seats,Trailer hitch                            1
# Alloy wheels,Catalytic Converter,Ski bag,Sport package,Voice Control                                          1
# Catalytic Converter,Roof rack,Sport seats,Sport suspension                                                    1
# Alloy wheels,Shift paddles,Ski bag,Sport seats,Sport suspension,Touch screen,Voice Control                    1
# Name: Extras, Length: 660, dtype: int64

# %%
fill_with(df, 'make_model', 'body_type', 'Extras', 'mode')
# Out:
# Number of NaN :  0
# ------------------
# Alloy wheels                                                                                               5792
# Alloy wheels,Touch screen                                                                                   697
# Roof rack                                                                                                   590
# Alloy wheels,Voice Control                                                                                  582
# Alloy wheels,Touch screen,Voice Control                                                                     544
#                                                                                                            ...
# Alloy wheels,Catalytic Converter,Shift paddles,Sport package,Sport seats,Sport suspension,Voice Control       1
# Alloy wheels,Catalytic Converter,Roof rack,Sport package,Sport seats,Trailer hitch                            1
# Alloy wheels,Catalytic Converter,Ski bag,Sport package,Voice Control                                          1
# Catalytic Converter,Roof rack,Sport seats,Sport suspension                                                    1
# Alloy wheels,Shift paddles,Ski bag,Sport seats,Sport suspension,Touch screen,Voice Control                    1
# Name: Extras, Length: 659, dtype: int64

# %% [markdown]
# ## - safety_security

# %%
info('safety_security')
# Out:
# Column Name    :  safety_security
# --------------------------------
# Number of Nulls       :  982
# Percentage of Nulls   :  % 6.17
# Number of Uniques     :  4443
# --------------------------------
#
# NaN                                                                                                                                                                                                                                                                                                                                                               982
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Fog lights,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                                                                                                                      538
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                                                                                                                                 480
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control,Xenon headlights                                                                                                                                275
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Fog lights,Immobilizer,Isofix,LED Daytime Running Lights,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                                                                                           272
#                                                                                                                                                                                                                                                                                                                                                                  ...
# ABS,Central door lock,Electronic stability control,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag                                                                                                                                                                                                                                              1
# ABS,Adaptive Cruise Control,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Emergency brake assistant,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                                                                                 1
# ABS,Adaptive Cruise Control,Alarm system,Central door lock,Driver-side airbag,Electronic stability control,Fog lights,Immobilizer,Isofix,Lane departure warning system,LED Daytime Running Lights,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control,Xenon headlights                                                1
# ABS,Adaptive Cruise Control,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Fog lights,Immobilizer,Isofix,Power steering,Tire pressure monitoring system,Traction control                                                                                                                                                  1
# ABS,Adaptive Cruise Control,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Emergency brake assistant,Fog lights,Immobilizer,Isofix,Lane departure warning system,LED Daytime Running Lights,LED Headlights,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traffic sign recognition      1
# Name: safety_security, Length: 4444, dtype: int64

# %%
fill_with(df, 'make_model', 'body_type', 'safety_security', 'mode')
# Out:
# Number of NaN :  0
# ------------------
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Fog lights,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                                                                                                                      712
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                                                                                                                                 480
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Fog lights,Immobilizer,Isofix,LED Daytime Running Lights,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                                                                                           373
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control,Xenon headlights                                                                                                                                352
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                                                                                                                                             323
#                                                                                                                                                                                                                                                                                                                                                                  ...
# ABS,Central door lock,Electronic stability control,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag                                                                                                                                                                                                                                              1
# ABS,Adaptive Cruise Control,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Emergency brake assistant,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                                                                                 1
# ABS,Adaptive Cruise Control,Alarm system,Central door lock,Driver-side airbag,Electronic stability control,Fog lights,Immobilizer,Isofix,Lane departure warning system,LED Daytime Running Lights,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control,Xenon headlights                                                1
# ABS,Adaptive Cruise Control,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Fog lights,Immobilizer,Isofix,Power steering,Tire pressure monitoring system,Traction control                                                                                                                                                  1
# ABS,Adaptive Cruise Control,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Emergency brake assistant,Fog lights,Immobilizer,Isofix,Lane departure warning system,LED Daytime Running Lights,LED Headlights,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traffic sign recognition      1
# Name: safety_security, Length: 4443, dtype: int64

# %% [markdown]
# ## - Gears

# %%
info('Gears')
# Out:
# Column Name    :  Gears
# --------------------------------
# Number of Nulls       :  4712
# Percentage of Nulls   :  % 29.6
# Number of Uniques     :  10
# --------------------------------
#
# 6.000     5822
# NaN       4712
# 5.000     3239
# 7.000     1908
# 8.000      224
# 9.000        6
# 1.000        2
# 3.000        2
# 4.000        2
# 2.000        1
# 50.000       1
# Name: Gears, dtype: int64

# %%
for group1 in list(df["make_model"].unique()):
    for group2 in list(df["body_type"].unique()):
        for group3 in list(df["Gearing Type"].unique()):
            cond1 = df["make_model"] == group1
            cond2 = (df["make_model"] == group1) & (df["body_type"] == group2)
            cond3 = (df["make_model"] == group1) & (
                df["body_type"] == group2) & (df["Gearing Type"] == group3)
            mode1 = list(df[cond1]["Gears"].mode())
            mode2 = list(df[cond2]["Gears"].mode())
            mode3 = list(df[cond3]["Gears"].mode())
            if mode3 != []:
                df.loc[cond3, "Gears"] = df.loc[cond3, "Gears"].fillna(
                    df[cond3]["Gears"].mode()[0])
            elif mode2 != []:
                df.loc[cond3, "Gears"] = df.loc[cond3, "Gears"].fillna(
                    df[cond2]["Gears"].mode()[0])
            elif mode1 != []:
                df.loc[cond3, "Gears"] = df.loc[cond3, "Gears"].fillna(
                    df[cond1]["Gears"].mode()[0])
            else:
                df.loc[cond3,
                       "Gears"] = df.loc[cond3,
                                         "Gears"].fillna(df["Gears"].mode()[0])

# %%
df["Gears"].value_counts(dropna=False)
# Out:
# 6.000     8615
# 5.000     4255
# 7.000     2810
# 8.000      225
# 9.000        6
# 1.000        2
# 3.000        2
# 4.000        2
# 2.000        1
# 50.000       1
# Name: Gears, dtype: int64

# %%
df.groupby(["make_model", "body_type", "Gearing Type", "Gears"]).price.describe()
# Out:
#                                                 count      mean      std  \
# make_model     body_type Gearing Type   Gears
# Audi A1        Compact   Automatic      5.000   3.000 22184.333 3421.302
#                                         6.000   6.000 21038.333 4282.039
#                                         7.000 452.000 21824.821 4534.304
#                                         8.000   1.000 16880.000      NaN
#                          Manual         5.000 497.000 16518.598 3108.721
# ...                                               ...       ...      ...
# Renault Espace Van       Automatic      9.000   6.000 52208.500 2735.327
#                          Manual         6.000  64.000 23744.578 6873.446
#                                         7.000   1.000 36590.000      NaN
#                          Semi-automatic 6.000  15.000 28234.667 9957.376
#                                         7.000   1.000 19900.000      NaN
#
#                                                     min       25%       50%  \
# make_model     body_type Gearing Type   Gears
# Audi A1        Compact   Automatic      5.000 18497.000 20648.500 22800.000
#                                         6.000 16430.000 18725.000 20920.000
#                                         7.000 13880.000 17989.750 21425.500
#                                         8.000 16880.000 16880.000 16880.000
#                          Manual         5.000  9950.000 14220.000 15900.000
# ...                                                 ...       ...       ...
# Renault Espace Van       Automatic      9.000 48765.000 50002.750 52711.000
#                          Manual         6.000 12614.000 18980.000 22147.500
#                                         7.000 36590.000 36590.000 36590.000
#                          Semi-automatic 6.000 16900.000 22950.000 24900.000
#                                         7.000 19900.000 19900.000 19900.000
#
#                                                     75%       max
# make_model     body_type Gearing Type   Gears
# Audi A1        Compact   Automatic      5.000 24028.000 25256.000
#                                         6.000 21060.000 28860.000
#                                         7.000 26460.000 29197.000
#                                         8.000 16880.000 16880.000
#                          Manual         5.000 16978.000 22990.000
# ...                                                 ...       ...
# Renault Espace Van       Automatic      9.000 54414.250 54982.000
#                          Manual         6.000 26585.000 47990.000
#                                         7.000 36590.000 36590.000
#                          Semi-automatic 6.000 31745.000 56950.000
#                                         7.000 19900.000 19900.000
#
# [160 rows x 8 columns]

# %% [markdown]
# ## - kW

# %%
info('kW')
# Out:
# Column Name    :  kW
# --------------------------------
# Number of Nulls       :  0
# Percentage of Nulls   :  % 0.0
# Number of Uniques     :  81
# --------------------------------
#
# 85.000     2542
# 66.000     2122
# 81.000     1402
# 100.000    1308
# 110.000    1112
#            ...
# 84.000        1
# 195.000       1
# 44.000        1
# 239.000       1
# 9.000         1
# Name: kW, Length: 81, dtype: int64

# %% [markdown]
# ## - Inspection_new

# %%
info('Inspection_new')
# Out:
# Column Name    :  Inspection_new
# --------------------------------
# Number of Nulls       :  11987
# Percentage of Nulls   :  % 75.3
# Number of Uniques     :  1
# --------------------------------
#
# NaN    11987
# Yes     3932
# Name: Inspection_new, dtype: int64

# %%
df.groupby(["make_model", "body_type", "age", "Inspection_new"]).price.describe()
# Out:
#                                                 count      mean      std  \
# make_model     body_type age   Inspection_new
# Audi A1        Compact   0.000 Yes            133.000 22542.248 3076.119
#                          1.000 Yes            118.000 17999.517 2293.776
#                          2.000 Yes             46.000 17045.652 2278.592
#                          3.000 Yes            106.000 14275.811 1923.911
#                Sedans    0.000 Yes             65.000 23604.262 3738.103
# ...                                               ...       ...      ...
# Renault Espace Off-Road  1.000 Yes              1.000 27850.000      NaN
#                Van       0.000 Yes             92.000 36090.402 5704.960
#                          1.000 Yes             33.000 33000.879 3414.041
#                          2.000 Yes              2.000 27139.500  211.425
#                          3.000 Yes             30.000 21790.100 3690.171
#
#                                                     min       25%       50%  \
# make_model     body_type age   Inspection_new
# Audi A1        Compact   0.000 Yes            14900.000 20388.000 22400.000
#                          1.000 Yes            13980.000 16445.000 16910.000
#                          2.000 Yes            12490.000 15610.000 15980.000
#                          3.000 Yes             9950.000 12922.500 13925.000
#                Sedans    0.000 Yes            15990.000 20985.000 22980.000
# ...                                                 ...       ...       ...
# Renault Espace Off-Road  1.000 Yes            27850.000 27850.000 27850.000
#                Van       0.000 Yes            28465.000 31862.500 34572.500
#                          1.000 Yes            29385.000 29990.000 31899.000
#                          2.000 Yes            26990.000 27064.750 27139.500
#                          3.000 Yes            12614.000 19085.000 21982.500
#
#                                                     75%       max
# make_model     body_type age   Inspection_new
# Audi A1        Compact   0.000 Yes            22950.000 29197.000
#                          1.000 Yes            19963.500 23829.000
#                          2.000 Yes            18367.000 21490.000
#                          3.000 Yes            15443.750 18880.000
#                Sedans    0.000 Yes            27370.000 29137.000
# ...                                                 ...       ...
# Renault Espace Off-Road  1.000 Yes            27850.000 27850.000
#                Van       0.000 Yes            39428.750 54120.000
#                          1.000 Yes            35300.000 38990.000
#                          2.000 Yes            27214.250 27289.000
#                          3.000 Yes            24825.000 26970.000
#
# [75 rows x 8 columns]

# %%
df["Inspection_new"].fillna("No", inplace=True) 

# If there is no given information in this column, it is most probably 'no'.

# %%
df["Inspection_new"].value_counts(dropna=False)
# Out:
# No     11987
# Yes     3932
# Name: Inspection_new, dtype: int64

# %% [markdown]
# ## - Upholstery_type

# %%
info('Upholstery_type')
# Out:
# Column Name    :  Upholstery_type
# --------------------------------
# Number of Nulls       :  4871
# Percentage of Nulls   :  % 30.6
# Number of Uniques     :  5
# --------------------------------
#
# Cloth           8423
# NaN             4871
# Part leather    1499
# Full leather    1009
# Velour            60
# alcantara         57
# Name: Upholstery_type, dtype: int64

# %%
fill_with(df,'make_model', 'body_type', 'Upholstery_type', 'mode')
# Out:
# Number of NaN :  0
# ------------------
# Cloth           12887
# Part leather     1508
# Full leather     1407
# Velour             60
# alcantara          57
# Name: Upholstery_type, dtype: int64

# %% [markdown]
# ## - Displacement_cc

# %%
info('Displacement_cc')
# Out:
# Column Name    :  Displacement_cc
# --------------------------------
# Number of Nulls       :  496
# Percentage of Nulls   :  % 3.12
# Number of Uniques     :  77
# --------------------------------
#
# 1598.000    4761
# 999.000     2438
# 1398.000    1314
# 1399.000     749
# 1229.000     677
#             ...
# 122.000        1
# 1198.000       1
# 1195.000       1
# 2967.000       1
# 1800.000       1
# Name: Displacement_cc, Length: 78, dtype: int64

# %%
df.groupby(["make_model", "kW","Displacement_cc"]).price.describe()
# Out:
#                                          count      mean      std       min  \
# make_model     kW      Displacement_cc
# Audi A1        0.000   999.000           1.000 22750.000      NaN 22750.000
#                60.000  929.000           4.000 15735.000  617.819 14980.000
#                        999.000         150.000 15194.107 1658.995 10900.000
#                66.000  1422.000        455.000 15750.576 2217.766 10490.000
#                        1596.000          1.000 15585.000      NaN 15585.000
# ...                                        ...       ...      ...       ...
# Renault Espace 165.000 1618.000          2.000 37484.500 2114.956 35989.000
#                        1798.000        187.000 37919.219 7790.956 26800.000
#                        1800.000          1.000 50750.000      NaN 50750.000
#                167.000 1798.000          2.000 37990.000 2828.427 35990.000
#                168.000 1798.000          3.000 38410.000 1712.659 36590.000
#
#                                              25%       50%       75%       max
# make_model     kW      Displacement_cc
# Audi A1        0.000   999.000         22750.000 22750.000 22750.000 22750.000
#                60.000  929.000         15355.000 15860.000 16240.000 16240.000
#                        999.000         13992.500 15552.500 15990.000 22390.000
#                66.000  1422.000        14200.000 15900.000 16800.000 23700.000
#                        1596.000        15585.000 15585.000 15585.000 15585.000
# ...                                          ...       ...       ...       ...
# Renault Espace 165.000 1618.000        36736.750 37484.500 38232.250 38980.000
#                        1798.000        31970.000 35880.000 40999.000 64332.000
#                        1800.000        50750.000 50750.000 50750.000 50750.000
#                167.000 1798.000        36990.000 37990.000 38990.000 39990.000
#                168.000 1798.000        37620.000 38650.000 39320.000 39990.000
#
# [310 rows x 8 columns]

# %%
fill_with(df, 'make_model', 'kW', 'Displacement_cc', 'mode')
# Out:
# Number of NaN :  0
# ------------------
# 1598.000    4983
# 999.000     2466
# 1398.000    1350
# 1399.000     765
# 1229.000     708
#             ...
# 122.000        1
# 1198.000       1
# 1195.000       1
# 2967.000       1
# 1800.000       1
# Name: Displacement_cc, Length: 77, dtype: int64

# %% [markdown]
# ## - Weight_kg

# %%
info('Weight_kg')
# Out:
# Column Name    :  Weight_kg
# --------------------------------
# Number of Nulls       :  6974
# Percentage of Nulls   :  % 43.81
# Number of Uniques     :  434
# --------------------------------
#
# NaN         6974
# 1163.000     574
# 1360.000     356
# 1165.000     301
# 1335.000     242
#             ...
# 1960.000       1
# 1258.000       1
# 1167.000       1
# 1331.000       1
# 2037.000       1
# Name: Weight_kg, Length: 435, dtype: int64

# %%
df.groupby(["make_model", "body_type", "Weight_kg"]).price.describe()
# Out:
#                                     count      mean      std       min  \
# make_model     body_type Weight_kg
# Audi A1        Compact   102.000    1.000 19229.000      NaN 19229.000
#                          1010.000   2.000 15450.000  707.107 14950.000
#                          1035.000   6.000 16796.667 2617.867 14390.000
#                          1040.000   2.000 20424.500 2933.786 18350.000
#                          1065.000  36.000 20971.778 1982.554 15500.000
# ...                                   ...       ...      ...       ...
# Renault Espace Van       1975.000   1.000 47580.000      NaN 47580.000
#                          2037.000   1.000 47950.000      NaN 47950.000
#                          2353.000   1.000 22990.000      NaN 22990.000
#                          2410.000   1.000 23990.000      NaN 23990.000
#                          2471.000   5.000 24738.000 8470.639 17400.000
#
#                                          25%       50%       75%       max
# make_model     body_type Weight_kg
# Audi A1        Compact   102.000   19229.000 19229.000 19229.000 19229.000
#                          1010.000  15200.000 15450.000 15700.000 15950.000
#                          1035.000  15892.500 15900.000 16575.000 21900.000
#                          1040.000  19387.250 20424.500 21461.750 22499.000
#                          1065.000  18987.500 21690.000 22400.000 23550.000
# ...                                      ...       ...       ...       ...
# Renault Espace Van       1975.000  47580.000 47580.000 47580.000 47580.000
#                          2037.000  47950.000 47950.000 47950.000 47950.000
#                          2353.000  22990.000 22990.000 22990.000 22990.000
#                          2410.000  23990.000 23990.000 23990.000 23990.000
#                          2471.000  20900.000 20900.000 25500.000 38990.000
#
# [855 rows x 8 columns]

# %%
fill_with(df, 'make_model', 'body_type', 'Weight_kg', 'mode')
# Out:
# Number of NaN :  0
# ------------------
# 1163.000    1582
# 1360.000    1419
# 1487.000     966
# 1165.000     855
# 1135.000     837
#             ...
# 1331.000       1
# 1132.000       1
# 1252.000       1
# 1792.000       1
# 2037.000       1
# Name: Weight_kg, Length: 434, dtype: int64

# %% [markdown]
# ## - cons_comb

# %%
info('cons_comb')
# Out:
# Column Name    :  cons_comb
# --------------------------------
# Number of Nulls       :  2033
# Percentage of Nulls   :  % 12.77
# Number of Uniques     :  72
# --------------------------------
#
# NaN       2033
# 5.400      770
# 3.900      733
# 4.000      713
# 5.100      657
#           ...
# 33.000       1
# 50.000       1
# 1.000        1
# 46.000       1
# 11.000       1
# Name: cons_comb, Length: 73, dtype: int64

# %%
df.groupby(["make_model", "body_type","cons_comb"]).price.describe()
# Out:
#                                      count      mean      std       min  \
# make_model     body_type cons_comb
# Audi A1        Compact   3.000       4.000 14370.250 4481.393 11100.000
#                          3.400       6.000 12755.000  900.750 11800.000
#                          3.500       3.000 14613.000 1848.098 12479.000
#                          3.600       5.000 13960.000 1232.071 12900.000
#                          3.700      50.000 15902.200 2960.324 12900.000
# ...                                    ...       ...      ...       ...
# Renault Espace Van       6.500       1.000 68320.000      NaN 68320.000
#                          6.800     115.000 34032.313 7847.720 25490.000
#                          7.400      61.000 38163.754 6406.548 28975.000
#                          7.600      14.000 52019.214 7596.268 38990.000
#                          46.000      1.000 25490.000      NaN 25490.000
#
#                                          25%       50%       75%       max
# make_model     body_type cons_comb
# Audi A1        Compact   3.000     11242.500 12840.500 15968.250 20700.000
#                          3.400     11987.500 12640.000 13570.000 13800.000
#                          3.500     14079.500 15680.000 15680.000 15680.000
#                          3.600     12900.000 13900.000 14200.000 15900.000
#                          3.700     13900.000 15040.000 15967.500 23500.000
# ...                                      ...       ...       ...       ...
# Renault Espace Van       6.500     68320.000 68320.000 68320.000 68320.000
#                          6.800     28237.500 31990.000 37470.000 58950.000
#                          7.400     33781.000 37475.000 39990.000 54500.000
#                          7.600     48387.500 51350.000 54982.000 64332.000
#                          46.000    25490.000 25490.000 25490.000 25490.000
#
# [540 rows x 8 columns]

# %%
for group1 in list(df["make_model"].unique()):
    for group2 in list(df["Displacement_cc"].unique()):
        for group3 in list(df["Fuel"].unique()):
            cond1 = df["make_model"] == group1
            cond2 = (df["make_model"] == group1) & (df["Displacement_cc"] == group2)
            cond3 = (df["make_model"] == group1) & (
                df["Displacement_cc"] == group2) & (df["Fuel"] == group3)
            mode1 = list(df[cond1]["cons_comb"].mode())
            mode2 = list(df[cond2]["cons_comb"].mode())
            mode3 = list(df[cond3]["cons_comb"].mode())
            if mode3 != []:
                df.loc[cond3, "cons_comb"] = df.loc[cond3, "cons_comb"].fillna(
                    df[cond3]["cons_comb"].mode()[0])
            elif mode2 != []:
                df.loc[cond3, "cons_comb"] = df.loc[cond3, "cons_comb"].fillna(
                    df[cond2]["cons_comb"].mode()[0])
            elif mode1 != []:
                df.loc[cond3, "cons_comb"] = df.loc[cond3, "cons_comb"].fillna(
                    df[cond1]["cons_comb"].mode()[0])
            else:
                df.loc[cond3,
                       "cons_comb"] = df.loc[cond3,
                                         "cons_comb"].fillna(df["cons_comb"].mode()[0])

# %%
df["cons_comb"].value_counts(dropna=False)
# Out:
# 4.000     967
# 5.400     942
# 4.700     821
# 4.400     774
# 3.900     770
#          ...
# 33.000      1
# 50.000      1
# 1.000       1
# 46.000      1
# 11.000      1
# Name: cons_comb, Length: 72, dtype: int64

# %% [markdown]
# ## - cons_city

# %%
info('cons_city')
# Out:
# Column Name    :  cons_city
# --------------------------------
# Number of Nulls       :  2436
# Percentage of Nulls   :  % 15.3
# Number of Uniques     :  86
# --------------------------------
#
# NaN       2436
# 5.000      669
# 5.800      633
# 4.500      580
# 4.300      533
#           ...
# 9.000        1
# 10.500       1
# 16.100       1
# 10.400       1
# 9.700        1
# Name: cons_city, Length: 87, dtype: int64

# %%
df.drop('cons_city', axis=1, inplace=True)

# %% [markdown]
# ## - cons_country

# %%
info('cons_country')
# Out:
# Column Name    :  cons_country
# --------------------------------
# Number of Nulls       :  2376
# Percentage of Nulls   :  % 14.93
# Number of Uniques     :  57
# --------------------------------
#
# NaN       2376
# 4.200     1178
# 3.700     1089
# 4.400      898
# 4.500      848
# 3.800      802
# 3.900      777
# 4.700      615
# 4.100      592
# 4.000      589
# 3.500      525
# 4.300      520
# 4.600      516
# 3.600      486
# 4.900      481
# 3.100      481
# 3.300      457
# 3.400      353
# 4.800      341
# 5.300      278
# 5.400      239
# 5.100      232
# 5.700      204
# 3.200      180
# 5.600      154
# 3.000      142
# 5.000      130
# 5.200      117
# 6.300       52
# 6.000       42
# 5.500       36
# 10.000      32
# 5.800       30
# 7.700       20
# 6.600       19
# 2.900       16
# 6.400       15
# 2.800        9
# 0.000        9
# 7.300        4
# 44.000       4
# 6.500        4
# 7.000        3
# 7.100        3
# 6.900        2
# 35.000       2
# 37.000       2
# 6.100        2
# 5.900        2
# 6.700        2
# 7.800        2
# 7.600        1
# 42.000       1
# 8.000        1
# 8.600        1
# 10.300       1
# 2.000        1
# 1.000        1
# Name: cons_country, dtype: int64

# %%
df.drop('cons_country', axis=1, inplace=True)

# %% [markdown]
# ## - CO2_Emission

# %%
info('CO2 Emission')
# Out:
# Column Name    :  CO2 Emission
# --------------------------------
# Number of Nulls       :  2436
# Percentage of Nulls   :  % 15.3
# Number of Uniques     :  120
# --------------------------------
#
# NaN        2436
# 120.000     740
# 99.000      545
# 97.000      537
# 104.000     501
#            ...
# 990.000       1
# 12.324        1
# 1.060         1
# 51.000        1
# 193.000       1
# Name: CO2 Emission, Length: 121, dtype: int64

# %%
df.groupby(["make_model", "Fuel", "CO2 Emission"]).price.describe()
# Out:
#                                       count      mean      std       min  \
# make_model     Fuel    CO2 Emission
# Audi A1        Benzine 1.000          1.000 20881.000      NaN 20881.000
#                        10.000       229.000 17938.812 2922.148  9950.000
#                        11.000        69.000 19511.565 2306.002 14930.000
#                        14.000         2.000 28750.000  268.701 28560.000
#                        97.000       287.000 14880.993 1803.783  8999.000
# ...                                     ...       ...      ...       ...
# Renault Espace Diesel  148.000       10.000 44191.100 4054.701 39070.000
#                        151.000        2.000 48150.000  806.102 47580.000
#                        168.000        5.000 46721.800 3235.820 42490.000
#                        174.000        1.000 43490.000      NaN 43490.000
#                        191.000        2.000 28465.000    0.000 28465.000
#
#                                           25%       50%       75%       max
# make_model     Fuel    CO2 Emission
# Audi A1        Benzine 1.000        20881.000 20881.000 20881.000 20881.000
#                        10.000       15960.000 17950.000 19990.000 29150.000
#                        11.000       17890.000 18990.000 21275.000 28980.000
#                        14.000       28655.000 28750.000 28845.000 28940.000
#                        97.000       13750.000 14931.000 15980.000 21800.000
# ...                                       ...       ...       ...       ...
# Renault Espace Diesel  148.000      40488.750 43985.000 46909.000 50170.000
#                        151.000      47865.000 48150.000 48435.000 48720.000
#                        168.000      44999.000 46680.000 48490.000 50950.000
#                        174.000      43490.000 43490.000 43490.000 43490.000
#                        191.000      28465.000 28465.000 28465.000 28465.000
#
# [499 rows x 8 columns]

# %%
fill_with(df, 'make_model', 'Fuel', 'CO2 Emission', 'median')
# Out:
# Number of NaN :  0
# ------------------
# 120.000    1081
# 97.000      742
# 104.000     739
# 99.000      545
# 128.000     535
#            ...
# 990.000       1
# 80.000        1
# 160.000       1
# 331.000       1
# 193.000       1
# Name: CO2 Emission, Length: 122, dtype: int64

# %% [markdown]
# ## - vat

# %%
info('vat')
# Out:
# Column Name    :  vat
# --------------------------------
# Number of Nulls       :  4513
# Percentage of Nulls   :  % 28.35
# Number of Uniques     :  2
# --------------------------------
#
# VAT deductible      10980
# NaN                  4513
# Price negotiable      426
# Name: vat, dtype: int64

# %%
df.groupby(["make_model", "body_type", "vat"]).price.describe()
# Out:
#                                                 count      mean       std  \
# make_model     body_type     vat
# Audi A1        Compact       Price negotiable   3.000 17631.667  1548.954
#                              VAT deductible   779.000 20018.999  4603.192
#                Coupe         VAT deductible     2.000 14925.000  1378.858
#                Sedans        Price negotiable  78.000 16224.308  3545.634
#                              VAT deductible   975.000 19370.279  4470.516
# ...                                               ...       ...       ...
# Renault Espace Station wagon VAT deductible    51.000 28585.098 10267.027
#                Transporter   Price negotiable   7.000 21500.000  3964.846
#                              VAT deductible    25.000 22685.480  4915.585
#                Van           Price negotiable  19.000 25957.789  3789.467
#                              VAT deductible   484.000 32989.397  9368.426
#
#                                                     min       25%       50%  \
# make_model     body_type     vat
# Audi A1        Compact       Price negotiable 15950.000 16947.500 17945.000
#                              VAT deductible    9950.000 16370.000 19990.000
#                Coupe         VAT deductible   13950.000 14437.500 14925.000
#                Sedans        Price negotiable 10800.000 13912.500 15299.500
#                              VAT deductible   10000.000 15950.000 18900.000
# ...                                                 ...       ...       ...
# Renault Espace Station wagon VAT deductible   17900.000 19950.000 23950.000
#                Transporter   Price negotiable 19000.000 19050.000 19900.000
#                              VAT deductible   14999.000 19450.000 20900.000
#                Van           Price negotiable 20999.000 22300.000 26950.000
#                              VAT deductible   12614.000 25990.000 31975.000
#
#                                                     75%       max
# make_model     body_type     vat
# Audi A1        Compact       Price negotiable 18472.500 19000.000
#                              VAT deductible   22730.000 31990.000
#                Coupe         VAT deductible   15412.500 15900.000
#                Sedans        Price negotiable 18112.500 33900.000
#                              VAT deductible   22315.000 35900.000
# ...                                                 ...       ...
# Renault Espace Station wagon VAT deductible   37945.000 52990.000
#                Transporter   Price negotiable 21750.000 30000.000
#                              VAT deductible   27000.000 32700.000
#                Van           Price negotiable 28250.000 32000.000
#                              VAT deductible   38110.000 68320.000
#
# [62 rows x 8 columns]

# %%
df.drop('vat', axis=1, inplace=True) 

# The both columns vat and price have same proportion in ratio, that's why we can drop it.

# %% [markdown]
# We  found that 'vat' column does not contribute significantly to the price column when the 'vat' column was grouped together with the 'make_model' and   'body_type' columns (and the standard deviation was too high).

# %% [markdown]
# ## - price

# %%
info('price')
# Out:
# Column Name    :  price
# --------------------------------
# Number of Nulls       :  0
# Percentage of Nulls   :  % 0.0
# Number of Uniques     :  2956
# --------------------------------
#
# 14990    154
# 15990    151
# 10990    139
# 15900    106
# 17990    102
#         ...
# 17559      1
# 17560      1
# 17570      1
# 17575      1
# 39875      1
# Name: price, Length: 2956, dtype: int64

# %%
df.shape
# Out:
# (15919, 24)

# %%
df.columns
# Out:
# Index(['make_model', 'body_type', 'price', 'km', 'kW', 'Type',
#        'Previous Owners', 'Nr. of Doors', 'Nr. of Seats', 'Gearing Type',
#        'Drive chain', 'Fuel', 'CO2 Emission', 'comfort_convenience',
#        'entertainment_media', 'Extras', 'safety_security', 'Gears',
#        'Inspection_new', 'age', 'Upholstery_type', 'Displacement_cc',
#        'Weight_kg', 'cons_comb'],
#       dtype='object')

# %%
df.duplicated().sum()
# Out:
# 1744

# %%
df.to_csv("filled_Null_AutoScout.csv", index=False)

# %% [markdown]
# ------------------------------------
# END OF THE PART - 2 : HANDLING WITH MISSING VALUES
